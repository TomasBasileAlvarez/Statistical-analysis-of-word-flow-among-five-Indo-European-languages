# %%
import advertools as adv
import pandas as pd
import numpy as np
import tqdm
import matplotlib.pyplot as plt

# %%
migrant = pd.read_csv("Migrant/migrant_1800.csv")
migrant.drop(migrant.columns[0],inplace=True,axis=1)
migrant
# Out:
#            word  year   count language    Rank
# 0            aa  1801      96  italian  4084.0
# 1            aa  1801     598  spanish  4473.0
# 2            aa  1807    4849   french  2994.0
# 3            aa  1942    3169   german  4923.0
# 4       abandon  1800    3124  english  3156.0
# ...         ...   ...     ...      ...     ...
# 14351     états  1810     528  italian  2840.0
# 14352     étoit  1800  151690   french     8.0
# 14353     étoit  1816     475   german  4194.0
# 14354  étranger  1800   12974   french   788.0
# 14355  étranger  1810     318  italian  4876.0
#
# [14356 rows x 5 columns]

# %%
def migrants(language_out,language_in,years,exclude=""):
    migrant_df = pd.read_csv("Migrant/migrant_1800.csv")
    migrant_df.drop(migrant_df.columns[0],inplace=True,axis=1)
    
    #Take only the first appearances of words
    first_appearance = migrant_df.drop_duplicates(subset='word', keep='first')
    
    #take the words created by the out language.
    out_words = first_appearance[first_appearance["language"] == language_out ]
    
    #Take the words that
    migrated_from_out = migrant_df[(migrant_df["word"].isin(out_words["word"])) & 
                               (migrant_df["year"].isin(years)) &
                                (migrant_df["language"] == language_in)
                               ]
    return(migrated_from_out)

migrants("italian","spanish",range(1850,2008),"")
# Out:
#            word  year  count language    Rank
# 174      adolfo  1864   3605  spanish  3979.0
# 238         agr  1951  10406  spanish  4983.0
# 240     agraria  1919   5606  spanish  4221.0
# 242     agrario  1914   4420  spanish  4732.0
# 253        agro  1978  26316  spanish  4794.0
# ...         ...   ...    ...      ...     ...
# 13902   villani  1854   1702  spanish  4780.0
# 13985  vitamina  1940  12760  spanish  3383.0
# 14059      vota  1882   2848  spanish  4451.0
# 14290    yndias  1871   2720  spanish  3744.0
# 14302     yslas  1873   2808  spanish  3374.0
#
# [206 rows x 5 columns]

# %%
def uset(language_out,language_in,year,years_acc,exclude):
    
    words = migrants(language_out,language_in,years_acc,exclude)["word"]
    
    lan_in_df = pd.read_csv("Top5000/"+"top_"+language_in + exclude+ ".csv",dtype={"0":str, "1":np.int32, "2":np.int32},
                         names = ["word","year","count"], header=None,index_col=False)
    
    lan_in_df['Rank'] = lan_in_df.groupby("year")["count"].rank(ascending=False, method='first')
    lan_in_df = lan_in_df.sort_values(by=["year", "Rank"])
    
    
    lan_in_year = lan_in_df[lan_in_df["year"]==year]
    
    normalization = np.sum(lan_in_year["count"])

    words_year = lan_in_year[lan_in_year["word"].isin(words)]
    
    
    frec = np.sum(words_year["count"])
#     print(frec/normalization)

#     return(words_year)
#     return(words_year,frec/normalization)
    return(words_year["word"].values, frec/normalization)

def use(language_out,language_in,years,exclude):
    words = []
    uses = []
    for year in tqdm.tqdm(years):
        a,b = uset(language_out,language_in,year,years,exclude)
        words.append(list(a))
        uses.append(b)
    return(words,uses)

# %%
words,uses = use("english","french",range(1850,2008+1),"_exc_all")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:46<00:00,  1.05s/it]

# %%
words,uses = use("spanish","german",range(1900,2008),"_exc_all")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 108/108 [01:57<00:00,  1.09s/it]

# %%
words
# Out:
# [['intellect', 'corporation', 'solutions', 'marlborough', 'intense'],
#  ['monk', 'gray'],
#  ['foix', 'circuit', 'corporation', 'permanent'],
#  ['intense', 'filaments'],
#  ['circuit'],
#  ['chili', 'patronage'],
#  ['circuit', 'shakspeare', 'peel', 'shall', 'commercial', 'monk'],
#  ['mill', 'commercial'],
#  ['circuit', 'international'],
#  ['circuit', 'intense'],
#  ['permanent', 'circuit', 'martyrs'],
#  ['eminence', 'arch', 'commercial', 'cloud', 'martyrs'],
#  ['russell', 'cloud', 'commercial', 'arch'],
#  ['arch', 'russell', 'cloud'],
#  ['silex', 'progressive', 'russell', 'solutions', 'permanent'],
#  ['russell', 'silex', 'solutions', 'correspondent', 'martyrs'],
#  ['martyrs',
#   'intense',
#   'correspondent',
#   'infection',
#   'solutions',
#   'progressive'],
#  ['silex', 'intense', 'solutions', 'permanent', 'commercial'],
#  ['trains',
#   'wagons',
#   'intense',
#   'silex',
#   'international',
#   'solutions',
#   'progressive'],
#  ['intense', 'silex', 'correspondent', 'solutions', 'international'],
#  ['silex',
#   'international',
#   'correspondent',
#   'progressive',
#   'arch',
#   'solutions'],
#  ['mac',
#   'granville',
#   'solutions',
#   'international',
#   'patrons',
#   'trains',
#   'permanent',
#   'wagons',
#   'intense'],
#  ['silex',
#   'international',
#   'trains',
#   'solutions',
#   'circuit',
#   'wagons',
#   'patrons',
#   'permanent'],
#  ['silex',
#   'international',
#   'solutions',
#   'patronage',
#   'trains',
#   'correspondent',
#   'circuit',
#   'intense',
#   'soc',
#   'altitude',
#   'bull',
#   'granville',
#   'permanent',
#   'wagons'],
#  ['silex',
#   'international',
#   'trains',
#   'solutions',
#   'arch',
#   'wagons',
#   'mac',
#   'intense',
#   'correspondent',
#   'commercial',
#   'mercy',
#   'soc',
#   'patronage',
#   'permanent',
#   'circuit'],
#  ['international',
#   'mac',
#   'silex',
#   'alfred',
#   'solutions',
#   'mercy',
#   'correspondent',
#   'patronage',
#   'soc',
#   'intense',
#   'trains',
#   'permanent'],
#  ['international',
#   'silex',
#   'soc',
#   'solutions',
#   'intense',
#   'correspondent',
#   'alfred',
#   'altitude',
#   'permanent'],
#  ['international',
#   'silex',
#   'roses',
#   'alfred',
#   'intense',
#   'soc',
#   'solutions',
#   'correspondent',
#   'altitude',
#   'arch',
#   'patronage',
#   'progressive',
#   'trains'],
#  ['international',
#   'silex',
#   'trains',
#   'solutions',
#   'intense',
#   'soc',
#   'circuit',
#   'correspondent',
#   'altitude',
#   'arch',
#   'alfred',
#   'commercial'],
#  ['international',
#   'silex',
#   'solutions',
#   'soc',
#   'patronage',
#   'intense',
#   'arch',
#   'correspondent',
#   'altitude',
#   'commercial',
#   'mill',
#   'progressive',
#   'alfred'],
#  ['international',
#   'trains',
#   'solutions',
#   'silex',
#   'soc',
#   'commercial',
#   'roses',
#   'intense',
#   'arch',
#   'patronage',
#   'correspondent',
#   'altitude',
#   'alfred',
#   'circuit'],
#  ['international',
#   'circuit',
#   'silex',
#   'soc',
#   'intense',
#   'trains',
#   'correspondent',
#   'solutions',
#   'altitude',
#   'commercial',
#   'arch',
#   'alfred',
#   'permanent'],
#  ['international',
#   'circuit',
#   'solutions',
#   'trains',
#   'intense',
#   'wagons',
#   'alfred',
#   'soc',
#   'arch',
#   'correspondent',
#   'commercial',
#   'silex',
#   'permanent',
#   'patrons',
#   'patronage',
#   'progressive'],
#  ['international',
#   'circuit',
#   'solutions',
#   'intense',
#   'trains',
#   'silex',
#   'roses',
#   'soc',
#   'commercial',
#   'alfred',
#   'correspondent',
#   'permanent',
#   'arch',
#   'congo'],
#  ['international',
#   'arch',
#   'solutions',
#   'congo',
#   'circuit',
#   'soc',
#   'intense',
#   'patrons',
#   'commercial',
#   'trains',
#   'ferry',
#   'silex',
#   'alfred',
#   'correspondent',
#   'altitude',
#   'corporation',
#   'wagons'],
#  ['international',
#   'congo',
#   'circuit',
#   'soc',
#   'solutions',
#   'commercial',
#   'silex',
#   'trains',
#   'intense',
#   'bull',
#   'patrons',
#   'roses',
#   'correspondent',
#   'altitude',
#   'corporation',
#   'alfred',
#   'ferry',
#   'arch',
#   'mill',
#   'spencer',
#   'permanent'],
#  ['international',
#   'circuit',
#   'congo',
#   'commercial',
#   'solutions',
#   'soc',
#   'trains',
#   'patrons',
#   'alfred',
#   'intense',
#   'arch',
#   'correspondent',
#   'altitude',
#   'silex',
#   'permanent',
#   'progressive'],
#  ['international',
#   'trains',
#   'circuit',
#   'solutions',
#   'commercial',
#   'soc',
#   'patrons',
#   'arch',
#   'bull',
#   'roses',
#   'suggestion',
#   'intense',
#   'congo',
#   'wagons',
#   'alfred',
#   'silex',
#   'correspondent',
#   'permanent',
#   'corporation',
#   'altitude'],
#  ['international',
#   'circuit',
#   'trains',
#   'congo',
#   'silex',
#   'solutions',
#   'wagons',
#   'soc',
#   'intense',
#   'commercial',
#   'arch',
#   'alfred',
#   'altitude',
#   'roses',
#   'patrons',
#   'correspondent',
#   'bull',
#   'permanent',
#   'corporation'],
#  ['international',
#   'circuit',
#   'arch',
#   'commercial',
#   'soc',
#   'trains',
#   'solutions',
#   'congo',
#   'patronage',
#   'patrons',
#   'silex',
#   'intense',
#   'roses',
#   'suggestion',
#   'alfred',
#   'progressive',
#   'correspondent',
#   'altitude',
#   'corporation',
#   'infection',
#   'wagons',
#   'permanent',
#   'bull'],
#  ['international',
#   'circuit',
#   'trains',
#   'patrons',
#   'arch',
#   'patronage',
#   'congo',
#   'solutions',
#   'wagons',
#   'commercial',
#   'intense',
#   'soc',
#   'alfred',
#   'altitude',
#   'rail',
#   'roses',
#   'permanent',
#   'corporation',
#   'stanley',
#   'correspondent',
#   'mac',
#   'silex',
#   'suggestion',
#   'infection'],
#  ['international',
#   'circuit',
#   'patrons',
#   'congo',
#   'trains',
#   'solutions',
#   'soc',
#   'arch',
#   'commercial',
#   'aluminium',
#   'silex',
#   'intense',
#   'infection',
#   'wagons',
#   'alfred',
#   'altitude',
#   'patronage',
#   'permanent',
#   'roses',
#   'correspondent',
#   'suggestion',
#   'bull',
#   'corporation'],
#  ['international',
#   'circuit',
#   'solutions',
#   'patrons',
#   'trains',
#   'infection',
#   'intense',
#   'commercial',
#   'soc',
#   'arch',
#   'congo',
#   'altitude',
#   'silex',
#   'alfred',
#   'wagons',
#   'corporation',
#   'correspondent',
#   'permanent',
#   'roses',
#   'bull',
#   'patronage',
#   'suggestion',
#   'progressive'],
#  ['international',
#   'circuit',
#   'patrons',
#   'soc',
#   'solutions',
#   'trains',
#   'intense',
#   'commercial',
#   'altitude',
#   'infection',
#   'congo',
#   'suggestion',
#   'alfred',
#   'arch',
#   'bull',
#   'chicago',
#   'patronage',
#   'correspondent',
#   'corporation',
#   'wagons',
#   'silex',
#   'roses',
#   'permanent',
#   'progressive'],
#  ['international',
#   'congo',
#   'solutions',
#   'circuit',
#   'arch',
#   'patrons',
#   'soc',
#   'intense',
#   'infection',
#   'trains',
#   'chicago',
#   'commercial',
#   'patronage',
#   'altitude',
#   'correspondent',
#   'alfred',
#   'wagons',
#   'roses',
#   'silex',
#   'permanent',
#   'progressive',
#   'corporation'],
#  ['international',
#   'congo',
#   'circuit',
#   'arch',
#   'solutions',
#   'patrons',
#   'infection',
#   'soc',
#   'intense',
#   'commercial',
#   'patronage',
#   'trains',
#   'corporation',
#   'alfred',
#   'altitude',
#   'permanent',
#   'correspondent',
#   'bull',
#   'roses',
#   'wagons',
#   'progressive',
#   'chicago',
#   'homestead'],
#  ['international',
#   'solutions',
#   'circuit',
#   'patrons',
#   'soc',
#   'intense',
#   'infection',
#   'commercial',
#   'congo',
#   'aluminium',
#   'arch',
#   'altitude',
#   'alfred',
#   'correspondent',
#   'trains',
#   'bull',
#   'roses',
#   'patronage',
#   'permanent',
#   'progressive'],
#  ['international',
#   'solutions',
#   'congo',
#   'circuit',
#   'patrons',
#   'intense',
#   'infection',
#   'trains',
#   'arch',
#   'soc',
#   'commercial',
#   'alfred',
#   'wagons',
#   'patronage',
#   'altitude',
#   'permanent',
#   'corporation',
#   'correspondent',
#   'roses',
#   'silex',
#   'progressive',
#   'bull',
#   'chili',
#   'aluminium'],
#  ['international',
#   'solutions',
#   'arch',
#   'circuit',
#   'congo',
#   'patrons',
#   'trains',
#   'intense',
#   'soc',
#   'commercial',
#   'infection',
#   'altitude',
#   'patronage',
#   'mac',
#   'alfred',
#   'correspondent',
#   'bull',
#   'wagons',
#   'permanent',
#   'corporation',
#   'colonial',
#   'aluminium',
#   'calcium',
#   'roses',
#   'anglo',
#   'progressive',
#   'arthur'],
#  ['international',
#   'congo',
#   'circuit',
#   'solutions',
#   'arch',
#   'commercial',
#   'patrons',
#   'soc',
#   'infection',
#   'intense',
#   'alfred',
#   'sand',
#   'altitude',
#   'silex',
#   'trains',
#   'colonial',
#   'permanent',
#   'corporation',
#   'correspondent',
#   'anglo',
#   'progressive',
#   'chili',
#   'formations',
#   'mac',
#   'roses',
#   'filaments',
#   'bull',
#   'patronage'],
#  ['international',
#   'solutions',
#   'soc',
#   'circuit',
#   'patrons',
#   'commercial',
#   'congo',
#   'infection',
#   'intense',
#   'arch',
#   'trains',
#   'corporation',
#   'altitude',
#   'alfred',
#   'permanent',
#   'colonial',
#   'wagons',
#   'patronage',
#   'bull',
#   'silex',
#   'correspondent',
#   'boers',
#   'paine',
#   'progressive',
#   'roses',
#   'suggestion',
#   'arthur',
#   'pin',
#   'age'],
#  ['international',
#   'solutions',
#   'patrons',
#   'circuit',
#   'congo',
#   'infection',
#   'soc',
#   'intense',
#   'arch',
#   'commercial',
#   'trains',
#   'alfred',
#   'patronage',
#   'altitude',
#   'silex',
#   'colonial',
#   'corporation',
#   'permanent',
#   'correspondent',
#   'bull',
#   'progressive',
#   'wagons',
#   'suggestion',
#   'roses',
#   'london',
#   'arthur',
#   'index',
#   'age',
#   'marks',
#   'formations'],
#  ['international',
#   'solutions',
#   'patrons',
#   'soc',
#   'congo',
#   'circuit',
#   'intense',
#   'commercial',
#   'infection',
#   'arch',
#   'trains',
#   'colonial',
#   'altitude',
#   'alfred',
#   'permanent',
#   'bull',
#   'corporation',
#   'patronage',
#   'boers',
#   'silex',
#   'correspondent',
#   'roses',
#   'suggestion',
#   'marks',
#   'wagons',
#   'progressive'],
#  ['international',
#   'arch',
#   'congo',
#   'solutions',
#   'circuit',
#   'patrons',
#   'infection',
#   'commercial',
#   'soc',
#   'intense',
#   'trains',
#   'permanent',
#   'colonial',
#   'corporation',
#   'alfred',
#   'altitude',
#   'correspondent',
#   'trusts',
#   'progressive',
#   'marks',
#   'trust',
#   'bull',
#   'wagons',
#   'silex',
#   'suggestion',
#   'roses',
#   'patronage',
#   'filaments'],
#  ['international',
#   'circuit',
#   'solutions',
#   'patrons',
#   'congo',
#   'intense',
#   'arch',
#   'commercial',
#   'infection',
#   'soc',
#   'corporation',
#   'trains',
#   'permanent',
#   'altitude',
#   'arthur',
#   'alfred',
#   'correspondent',
#   'colonial',
#   'progressive',
#   'roses',
#   'bull',
#   'wagons',
#   'aspects',
#   'james'],
#  ['international',
#   'solutions',
#   'patrons',
#   'circuit',
#   'soc',
#   'congo',
#   'commercial',
#   'infection',
#   'intense',
#   'arch',
#   'trains',
#   'altitude',
#   'colonial',
#   'permanent',
#   'bull',
#   'wagons',
#   'alfred',
#   'arthur',
#   'patronage',
#   'correspondent',
#   'silex',
#   'progressive',
#   'anglo',
#   'aluminium',
#   'marks',
#   'location',
#   'roses',
#   'formations',
#   'corporation',
#   'mac'],
#  ['international',
#   'congo',
#   'solutions',
#   'soc',
#   'infection',
#   'patrons',
#   'commercial',
#   'intense',
#   'arch',
#   'circuit',
#   'colonial',
#   'trains',
#   'altitude',
#   'alfred',
#   'permanent',
#   'silex',
#   'correspondent',
#   'bull',
#   'progressive',
#   'marks',
#   'aluminium',
#   'arthur',
#   'wagons',
#   'patronage',
#   'aspects',
#   'published',
#   'chili',
#   'formations'],
#  ['international',
#   'congo',
#   'solutions',
#   'patrons',
#   'soc',
#   'arch',
#   'intense',
#   'infection',
#   'commercial',
#   'patronage',
#   'trains',
#   'circuit',
#   'colonial',
#   'altitude',
#   'wagons',
#   'permanent',
#   'bull',
#   'alfred',
#   'correspondent',
#   'silex',
#   'formations',
#   'progressive',
#   'arthur',
#   'aspects',
#   'calcium',
#   'limitation',
#   'london',
#   'age',
#   'corporation',
#   'index',
#   'chili'],
#  ['international',
#   'congo',
#   'arch',
#   'solutions',
#   'patrons',
#   'commercial',
#   'soc',
#   'intense',
#   'circuit',
#   'trains',
#   'wagons',
#   'bull',
#   'infection',
#   'altitude',
#   'permanent',
#   'colonial',
#   'marks',
#   'alfred',
#   'progressive',
#   'arthur',
#   'corporation',
#   'correspondent',
#   'aspects',
#   'james',
#   'silex',
#   'roses',
#   'index',
#   'limitation'],
#  ['international',
#   'congo',
#   'arch',
#   'soc',
#   'solutions',
#   'patrons',
#   'intense',
#   'commercial',
#   'infection',
#   'altitude',
#   'trains',
#   'circuit',
#   'permanent',
#   'bull',
#   'alfred',
#   'silex',
#   'correspondent',
#   'wagons',
#   'aluminium',
#   'aspects',
#   'progressive',
#   'age',
#   'formations',
#   'colonial',
#   'james',
#   'arthur',
#   'marks',
#   'cf',
#   'roses',
#   'corporation',
#   'index'],
#  ['international',
#   'arch',
#   'solutions',
#   'congo',
#   'soc',
#   'intense',
#   'patrons',
#   'circuit',
#   'commercial',
#   'altitude',
#   'infection',
#   'trains',
#   'alfred',
#   'permanent',
#   'aspects',
#   'correspondent',
#   'suggestion',
#   'bull',
#   'colonial',
#   'formations',
#   'james',
#   'age',
#   'progressive',
#   'silex',
#   'wagons',
#   'aluminium',
#   'roses',
#   'london',
#   'calcium',
#   'anglo',
#   'index'],
#  ['international',
#   'congo',
#   'arch',
#   'solutions',
#   'soc',
#   'circuit',
#   'intense',
#   'patrons',
#   'commercial',
#   'altitude',
#   'bull',
#   'permanent',
#   'infection',
#   'trains',
#   'correspondent',
#   'alfred',
#   'james',
#   'aspects',
#   'colonial',
#   'shall',
#   'progressive',
#   'london',
#   'roses',
#   'age',
#   'aluminium',
#   'wagons',
#   'patronage',
#   'index',
#   'suggestion',
#   'corporation',
#   'mental'],
#  ['international',
#   'congo',
#   'arch',
#   'solutions',
#   'soc',
#   'intense',
#   'patrons',
#   'commercial',
#   'infection',
#   'bull',
#   'circuit',
#   'permanent',
#   'trains',
#   'altitude',
#   'alfred',
#   'wagons',
#   'aspects',
#   'correspondent',
#   'corporation',
#   'london',
#   'colonial',
#   'progressive',
#   'william',
#   'james',
#   'arthur',
#   'age',
#   'marks',
#   'suggestion',
#   'formations'],
#  ['international',
#   'congo',
#   'arch',
#   'solutions',
#   'soc',
#   'intense',
#   'infection',
#   'commercial',
#   'patrons',
#   'alfred',
#   'circuit',
#   'bull',
#   'altitude',
#   'permanent',
#   'aspects',
#   'trains',
#   'james',
#   'london',
#   'colonial',
#   'correspondent',
#   'panama',
#   'roses',
#   'progressive',
#   'wagons',
#   'marks',
#   'cycle',
#   'age',
#   'cf',
#   'index',
#   'patronage',
#   'arthur',
#   'formations',
#   'pin',
#   'incidents'],
#  ['international',
#   'arch',
#   'solutions',
#   'congo',
#   'soc',
#   'intense',
#   'commercial',
#   'infection',
#   'circuit',
#   'trains',
#   'altitude',
#   'patrons',
#   'alfred',
#   'permanent',
#   'aspects',
#   'london',
#   'correspondent',
#   'bull',
#   'wagons',
#   'marks',
#   'progressive',
#   'age',
#   'roses',
#   'colonial',
#   'incidents',
#   'information',
#   'index'],
#  ['international',
#   'arch',
#   'anglo',
#   'trains',
#   'solutions',
#   'intense',
#   'marks',
#   'commercial',
#   'slave',
#   'infection',
#   'soc',
#   'wagons',
#   'formations',
#   'congo',
#   'bull',
#   'alfred',
#   'colonial',
#   'altitude',
#   'information',
#   'hostile',
#   'permanent',
#   'grey',
#   'aspects',
#   'chili',
#   'incidents',
#   'correspondent',
#   'william',
#   'circuit',
#   'arthur',
#   'edward',
#   'wilson'],
#  ['international',
#   'intense',
#   'marks',
#   'solutions',
#   'commercial',
#   'capture',
#   'infection',
#   'trains',
#   'wagons',
#   'soc',
#   'arch',
#   'altitude',
#   'colonial',
#   'circuit',
#   'permanent',
#   'alfred',
#   'wilson',
#   'formations',
#   'taxation',
#   'anglo',
#   'aspects',
#   'stocks',
#   'correspondent',
#   'patrons',
#   'hostile',
#   'bull',
#   'congo',
#   'drainage',
#   'chili',
#   'information',
#   'incidents'],
#  ['international',
#   'wilson',
#   'solutions',
#   'trains',
#   'infection',
#   'commercial',
#   'intense',
#   'wagons',
#   'slave',
#   'soc',
#   'arch',
#   'altitude',
#   'permanent',
#   'formations',
#   'congo',
#   'circuit',
#   'taxation',
#   'alfred',
#   'marks',
#   'aspects',
#   'patrons',
#   'colonial',
#   'restrictions',
#   'correspondent',
#   'aluminium',
#   'stocks',
#   'bull',
#   'anglo',
#   'lloyd',
#   'hostile',
#   'information',
#   'progressive',
#   'london',
#   'incidents'],
#  ['international',
#   'wilson',
#   'solutions',
#   'congo',
#   'commercial',
#   'intense',
#   'slave',
#   'infection',
#   'soc',
#   'trains',
#   'wagons',
#   'altitude',
#   'colonial',
#   'aluminium',
#   'permanent',
#   'marks',
#   'lloyd',
#   'restrictions',
#   'arch',
#   'circuit',
#   'alfred',
#   'aspects',
#   'anglo',
#   'hostile',
#   'information',
#   'wagon',
#   'correspondent',
#   'bull',
#   'patrons',
#   'capture',
#   'incidents',
#   'age',
#   'arthur',
#   'formations',
#   'cycle'],
#  ['international',
#   'wilson',
#   'solutions',
#   'circuit',
#   'congo',
#   'soc',
#   'intense',
#   'commercial',
#   'infection',
#   'trains',
#   'arch',
#   'altitude',
#   'wagons',
#   'patrons',
#   'colonial',
#   'permanent',
#   'slave',
#   'formations',
#   'alfred',
#   'correspondent',
#   'aspects',
#   'bull',
#   'lloyd',
#   'marks',
#   'reconstruction',
#   'restrictions',
#   'aluminium',
#   'anglo',
#   'information',
#   'james',
#   'limitation',
#   'silex',
#   'hostile',
#   'william',
#   'coke',
#   'progressive',
#   'chili',
#   'incidents',
#   'suggestion',
#   'roses',
#   'effective',
#   'stocks'],
#  ['international',
#   'solutions',
#   'circuit',
#   'congo',
#   'intense',
#   'infection',
#   'commercial',
#   'wilson',
#   'soc',
#   'trains',
#   'permanent',
#   'aspects',
#   'altitude',
#   'colonial',
#   'correspondent',
#   'patrons',
#   'marks',
#   'aluminium',
#   'wagons',
#   'arch',
#   'cycle',
#   'james',
#   'lloyd',
#   'alfred',
#   'limitation',
#   'age',
#   'progressive',
#   'anglo',
#   'coke',
#   'reconstruction',
#   'formations',
#   'information',
#   'cf',
#   'bull',
#   'restrictions',
#   'index',
#   'london',
#   'effective',
#   'law'],
#  ['international',
#   'solutions',
#   'arch',
#   'commercial',
#   'intense',
#   'permanent',
#   'infection',
#   'soc',
#   'congo',
#   'marks',
#   'circuit',
#   'colonial',
#   'altitude',
#   'wilson',
#   'aspects',
#   'aluminium',
#   'trains',
#   'patrons',
#   'capture',
#   'wagons',
#   'lloyd',
#   'correspondent',
#   'progressive',
#   'hostile',
#   'age',
#   'index',
#   'alfred',
#   'bull',
#   'anglo',
#   'james',
#   'information',
#   'limitation',
#   'coke',
#   'formations',
#   'reconstruction',
#   'cycle',
#   'stocks',
#   'restrictions',
#   'silex',
#   'london'],
#  ['international',
#   'solutions',
#   'soc',
#   'marks',
#   'commercial',
#   'lloyd',
#   'congo',
#   'intense',
#   'arch',
#   'circuit',
#   'infection',
#   'altitude',
#   'permanent',
#   'colonial',
#   'aspects',
#   'james',
#   'correspondent',
#   'bull',
#   'wagons',
#   'reconstruction',
#   'mark',
#   'limitation',
#   'trains',
#   'patrons',
#   'anglo',
#   'alfred',
#   'wilson',
#   'formations',
#   'progressive',
#   'cycle',
#   'london',
#   'information',
#   'index',
#   'age',
#   'roses',
#   'cf',
#   'gravitation',
#   'changes',
#   'effective',
#   'coke'],
#  ['international',
#   'solutions',
#   'commercial',
#   'soc',
#   'congo',
#   'marks',
#   'arch',
#   'intense',
#   'circuit',
#   'aspects',
#   'infection',
#   'permanent',
#   'colonial',
#   'james',
#   'altitude',
#   'wagons',
#   'bull',
#   'correspondent',
#   'alfred',
#   'index',
#   'patrons',
#   'mark',
#   'anglo',
#   'coke',
#   'reconstruction',
#   'trains',
#   'progressive',
#   'formations',
#   'william',
#   'limitation',
#   'cf',
#   'age',
#   'wilson',
#   'cycle',
#   'palestine',
#   'corporation',
#   'roses',
#   'effective',
#   'information',
#   'london',
#   'lloyd',
#   'lectures',
#   'silex',
#   'hostile'],
#  ['international',
#   'solutions',
#   'congo',
#   'soc',
#   'commercial',
#   'intense',
#   'circuit',
#   'infection',
#   'arch',
#   'marks',
#   'altitude',
#   'aspects',
#   'bull',
#   'patrons',
#   'permanent',
#   'colonial',
#   'alfred',
#   'coke',
#   'correspondent',
#   'london',
#   'wagons',
#   'index',
#   'anglo',
#   'trains',
#   'formations',
#   'wilson',
#   'cycle',
#   'mac',
#   'progressive',
#   'age',
#   'effective',
#   'changes',
#   'information',
#   'limitation',
#   'aluminium',
#   'silex',
#   'stable',
#   'palestine',
#   'roses',
#   'james'],
#  ['international',
#   'soc',
#   'solutions',
#   'congo',
#   'commercial',
#   'infection',
#   'intense',
#   'arch',
#   'aspects',
#   'altitude',
#   'permanent',
#   'bull',
#   'colonial',
#   'marks',
#   'alfred',
#   'immigration',
#   'correspondent',
#   'index',
#   'circuit',
#   'london',
#   'cycle',
#   'swift',
#   'information',
#   'patrons',
#   'anglo',
#   'progressive',
#   'limitation',
#   'formations',
#   'trains',
#   'james',
#   'roses',
#   'age',
#   'incidents',
#   'wagons',
#   'stable',
#   'effective',
#   'calcium',
#   'changes'],
#  ['international',
#   'soc',
#   'solutions',
#   'congo',
#   'commercial',
#   'intense',
#   'permanent',
#   'infection',
#   'aspects',
#   'circuit',
#   'bull',
#   'arch',
#   'marks',
#   'altitude',
#   'wagons',
#   'formations',
#   'trains',
#   'correspondent',
#   'age',
#   'cycle',
#   'anglo',
#   'limitation',
#   'colonial',
#   'alfred',
#   'progressive',
#   'london',
#   'index',
#   'patrons',
#   'information',
#   'roses',
#   'stable',
#   'coke',
#   'effective',
#   'immigration',
#   'incidents',
#   'silex',
#   'james',
#   'hostile',
#   'changes',
#   'arthur',
#   'post'],
#  ['international',
#   'soc',
#   'solutions',
#   'infection',
#   'intense',
#   'commercial',
#   'arch',
#   'aspects',
#   'congo',
#   'bull',
#   'permanent',
#   'correspondent',
#   'cycle',
#   'age',
#   'altitude',
#   'trains',
#   'colonial',
#   'index',
#   'patrons',
#   'progressive',
#   'anglo',
#   'alfred',
#   'wagons',
#   'limitation',
#   'circuit',
#   'london',
#   'formations',
#   'information',
#   'law',
#   'marks',
#   'shakespeare',
#   'shall',
#   'cf',
#   'james',
#   'irrigation',
#   'effective',
#   'stable',
#   'post'],
#  ['international',
#   'solutions',
#   'congo',
#   'soc',
#   'commercial',
#   'infection',
#   'permanent',
#   'aspects',
#   'intense',
#   'altitude',
#   'arch',
#   'bull',
#   'colonial',
#   'index',
#   'limitation',
#   'circuit',
#   'information',
#   'formations',
#   'trains',
#   'age',
#   'correspondent',
#   'london',
#   'cycle',
#   'alfred',
#   'marks',
#   'progressive',
#   'wagons',
#   'anglo',
#   'patrons',
#   'roses',
#   'incidents',
#   'restrictions',
#   'james',
#   'law',
#   'coke',
#   'film',
#   'effective',
#   'post'],
#  ['international',
#   'solutions',
#   'soc',
#   'congo',
#   'commercial',
#   'infection',
#   'aspects',
#   'intense',
#   'anglo',
#   'permanent',
#   'arch',
#   'altitude',
#   'information',
#   'bull',
#   'limitation',
#   'colonial',
#   'salisbury',
#   'age',
#   'mac',
#   'incidents',
#   'formations',
#   'young',
#   'james',
#   'circuit',
#   'alfred',
#   'correspondent',
#   'progressive',
#   'trains',
#   'marks',
#   'london',
#   'cycle',
#   'arthur',
#   'effective',
#   'hostile',
#   'index',
#   'post',
#   'palestine',
#   'film',
#   'patrons',
#   'cf',
#   'wagons',
#   'arrangements',
#   'shakespeare'],
#  ['international',
#   'congo',
#   'soc',
#   'infection',
#   'cf',
#   'solutions',
#   'arch',
#   'aspects',
#   'commercial',
#   'intense',
#   'colonial',
#   'permanent',
#   'bull',
#   'limitation',
#   'altitude',
#   'circuit',
#   'correspondent',
#   'index',
#   'progressive',
#   'cycle',
#   'age',
#   'formations',
#   'anglo',
#   'london',
#   'trains',
#   'post',
#   'alfred',
#   'information',
#   'wagons',
#   'wilson',
#   'marks',
#   'effective',
#   'incidents',
#   'patrons',
#   'hostile',
#   'film',
#   'calcium',
#   'palestine',
#   'immigration',
#   'restrictions',
#   'mac',
#   'james',
#   'young'],
#  ['international',
#   'congo',
#   'solutions',
#   'soc',
#   'infection',
#   'commercial',
#   'aspects',
#   'colonial',
#   'intense',
#   'permanent',
#   'altitude',
#   'bull',
#   'london',
#   'arch',
#   'film',
#   'circuit',
#   'formations',
#   'correspondent',
#   'james',
#   'index',
#   'limitation',
#   'cycle',
#   'progressive',
#   'age',
#   'information',
#   'effective',
#   'alfred',
#   'trains',
#   'cf',
#   'arthur',
#   'wagons',
#   'calcium',
#   'anglo',
#   'stocks',
#   'stable',
#   'incidents',
#   'william'],
#  ['international',
#   'congo',
#   'solutions',
#   'soc',
#   'infection',
#   'cf',
#   'aspects',
#   'commercial',
#   'arch',
#   'intense',
#   'bull',
#   'permanent',
#   'colonial',
#   'limitation',
#   'altitude',
#   'london',
#   'information',
#   'formations',
#   'correspondent',
#   'effective',
#   'index',
#   'age',
#   'circuit',
#   'progressive',
#   'cycle',
#   'palestine',
#   'wagons',
#   'calcium',
#   'film',
#   'trains',
#   'alfred',
#   'anglo',
#   'post',
#   'restrictions',
#   'arthur',
#   'hostile',
#   'incidents',
#   'initial',
#   'marks',
#   'chili',
#   'stable',
#   'roses',
#   'stocks',
#   'wagon'],
#  ['international',
#   'soc',
#   'infection',
#   'solutions',
#   'arch',
#   'circuit',
#   'congo',
#   'bull',
#   'aspects',
#   'cf',
#   'intense',
#   'commercial',
#   'altitude',
#   'permanent',
#   'age',
#   'cycle',
#   'formations',
#   'colonial',
#   'correspondent',
#   'trains',
#   'london',
#   'circuits',
#   'index',
#   'limitation',
#   'progressive',
#   'anglo',
#   'alfred',
#   'information',
#   'film',
#   'wagons',
#   'james',
#   'post',
#   'calcium',
#   'restrictions',
#   'effective',
#   'wilson',
#   'stable',
#   'william',
#   'lectures',
#   'roses',
#   'incidents'],
#  ['international',
#   'soc',
#   'solutions',
#   'congo',
#   'infection',
#   'arch',
#   'aspects',
#   'intense',
#   'altitude',
#   'commercial',
#   'bull',
#   'permanent',
#   'colonial',
#   'formations',
#   'circuit',
#   'index',
#   'cycle',
#   'correspondent',
#   'limitation',
#   'cf',
#   'calcium',
#   'information',
#   'progressive',
#   'age',
#   'london',
#   'corporation',
#   'med',
#   'effective',
#   'post',
#   'alfred',
#   'stable',
#   'anglo',
#   'film',
#   'restrictions',
#   'trains',
#   'mac',
#   'initial',
#   'roosevelt',
#   'stocks',
#   'dollar',
#   'law',
#   'aluminium'],
#  ['international',
#   'cf',
#   'soc',
#   'solutions',
#   'infection',
#   'congo',
#   'aspects',
#   'arch',
#   'intense',
#   'bull',
#   'circuit',
#   'commercial',
#   'altitude',
#   'cycle',
#   'correspondent',
#   'permanent',
#   'colonial',
#   'age',
#   'formations',
#   'information',
#   'index',
#   'progressive',
#   'london',
#   'shelley',
#   'initial',
#   'alfred',
#   'post',
#   'corporation',
#   'calcium',
#   'stable',
#   'limitation',
#   'aluminium',
#   'film',
#   'effective',
#   'anglo',
#   'butler',
#   'appellation',
#   'plants',
#   'restrictions'],
#  ['international',
#   'soc',
#   'solutions',
#   'infection',
#   'congo',
#   'arch',
#   'aspects',
#   'bull',
#   'intense',
#   'altitude',
#   'commercial',
#   'colonial',
#   'permanent',
#   'correspondent',
#   'formations',
#   'london',
#   'age',
#   'cycle',
#   'circuit',
#   'index',
#   'progressive',
#   'information',
#   'calcium',
#   'palestine',
#   'limitation',
#   'plants',
#   'alfred',
#   'anglo',
#   'effective',
#   'corporation',
#   'appellation',
#   'cf',
#   'stable',
#   'post',
#   'plantation',
#   'film',
#   'initial',
#   'aluminium',
#   'trains',
#   'stocks',
#   'med',
#   'patrons',
#   'hostile',
#   'restrictions'],
#  ['international',
#   'soc',
#   'congo',
#   'solutions',
#   'infection',
#   'aspects',
#   'bull',
#   'arch',
#   'intense',
#   'commercial',
#   'circuit',
#   'formations',
#   'permanent',
#   'altitude',
#   'colonial',
#   'cycle',
#   'correspondent',
#   'index',
#   'information',
#   'progressive',
#   'age',
#   'london',
#   'calcium',
#   'cf',
#   'film',
#   'post',
#   'anglo',
#   'limitation',
#   'patrons',
#   'initial',
#   'appellation',
#   'effective',
#   'corporation',
#   'alfred',
#   'stable',
#   'palestine',
#   'stocks',
#   'plantation',
#   'trains',
#   'incidents',
#   'aluminium',
#   'sanguine',
#   'plants',
#   'restrictions',
#   'changes',
#   'education'],
#  ['international',
#   'soc',
#   'congo',
#   'infection',
#   'solutions',
#   'aspects',
#   'arch',
#   'intense',
#   'commercial',
#   'bull',
#   'permanent',
#   'altitude',
#   'cycle',
#   'london',
#   'age',
#   'circuit',
#   'information',
#   'correspondent',
#   'colonial',
#   'formations',
#   'progressive',
#   'index',
#   'anglo',
#   'film',
#   'post',
#   'limitation',
#   'cf',
#   'effective',
#   'plantation',
#   'changes',
#   'chamberlain',
#   'calcium',
#   'stable',
#   'restrictions',
#   'alfred',
#   'plants',
#   'initial',
#   'law',
#   'hostile',
#   'incidents',
#   'palestine',
#   'education',
#   'aluminium',
#   'stocks',
#   'stock',
#   'med',
#   'patrons',
#   'report',
#   'appellation',
#   'chili',
#   'corporation',
#   'william',
#   'test',
#   'infections',
#   'irrigation'],
#  ['international',
#   'soc',
#   'arch',
#   'solutions',
#   'congo',
#   'infection',
#   'aspects',
#   'bull',
#   'commercial',
#   'intense',
#   'altitude',
#   'formations',
#   'circuit',
#   'cycle',
#   'permanent',
#   'age',
#   'correspondent',
#   'colonial',
#   'information',
#   'progressive',
#   'changes',
#   'calcium',
#   'index',
#   'stocks',
#   'anglo',
#   'restrictions',
#   'post',
#   'test',
#   'london',
#   'corporation',
#   'limitation',
#   'stable',
#   'film',
#   'cf',
#   'aluminium',
#   'effective',
#   'plantation',
#   'passive',
#   'alfred',
#   'wagons',
#   'trains',
#   'initial',
#   'incidents',
#   'roosevelt',
#   'stock',
#   'plants',
#   'chamberlain',
#   'appellation',
#   'patrons',
#   'pin'],
#  ['international',
#   'soc',
#   'congo',
#   'solutions',
#   'bull',
#   'aspects',
#   'altitude',
#   'arch',
#   'infection',
#   'intense',
#   'permanent',
#   'formations',
#   'cycle',
#   'cf',
#   'correspondent',
#   'information',
#   'commercial',
#   'age',
#   'plantation',
#   'london',
#   'circuit',
#   'anglo',
#   'stocks',
#   'aluminium',
#   'plants',
#   'changes',
#   'colonial',
#   'index',
#   'progressive',
#   'film',
#   'restrictions',
#   'stable',
#   'reconstruction',
#   'calcium',
#   'alfred',
#   'limitation',
#   'effective',
#   'version',
#   'corporation',
#   'initial',
#   'roses',
#   'wagons',
#   'report',
#   'med',
#   'test',
#   'support'],
#  ['international',
#   'soc',
#   'solutions',
#   'congo',
#   'bull',
#   'circuit',
#   'aspects',
#   'arch',
#   'corporation',
#   'altitude',
#   'intense',
#   'formations',
#   'correspondent',
#   'permanent',
#   'cycle',
#   'stocks',
#   'infection',
#   'age',
#   'cf',
#   'information',
#   'reconstruction',
#   'commercial',
#   'colonial',
#   'calcium',
#   'anglo',
#   'initial',
#   'act',
#   'progressive',
#   'stable',
#   'limitation',
#   'patrons',
#   'plantation',
#   'shall',
#   'aluminium',
#   'education',
#   'restrictions',
#   'clan',
#   'effective',
#   'index',
#   'film',
#   'plants',
#   'roses',
#   'post',
#   'london',
#   'alfred',
#   'pin',
#   'time',
#   'geo',
#   'test',
#   'case'],
#  ['international',
#   'congo',
#   'ass',
#   'soc',
#   'aspects',
#   'solutions',
#   'bull',
#   'altitude',
#   'formations',
#   'corporation',
#   'cycle',
#   'infection',
#   'arch',
#   'intense',
#   'age',
#   'correspondent',
#   'plants',
#   'permanent',
#   'cf',
#   'information',
#   'plantation',
#   'reconstruction',
#   'pin',
#   'colonial',
#   'commercial',
#   'calcium',
#   'post',
#   'index',
#   'intellect',
#   'progressive',
#   'anglo',
#   'circuit',
#   'limitation',
#   'stocks',
#   'alfred',
#   'effective',
#   'initial',
#   'restrictions',
#   'stable',
#   'roosevelt',
#   'film',
#   'wagons',
#   'clan',
#   'shall',
#   'london',
#   'editions',
#   'trains',
#   'case',
#   'calories',
#   'patrons'],
#  ['international',
#   'congo',
#   'solutions',
#   'soc',
#   'aspects',
#   'corporation',
#   'cycle',
#   'bull',
#   'intense',
#   'permanent',
#   'altitude',
#   'correspondent',
#   'arch',
#   'anglo',
#   'information',
#   'commercial',
#   'colonial',
#   'age',
#   'formations',
#   'reconstruction',
#   'aluminium',
#   'cf',
#   'progressive',
#   'stable',
#   'initial',
#   'circuit',
#   'stocks',
#   'calcium',
#   'infection',
#   'attitudes',
#   'patrons',
#   'pin',
#   'fluctuations',
#   'limitation',
#   'alfred',
#   'editions',
#   'index',
#   'film',
#   'effective',
#   'arthur',
#   'post',
#   'restrictions',
#   'roosevelt',
#   'appellation',
#   'stock',
#   'london',
#   'education',
#   'support',
#   'case',
#   'test'],
#  ['international',
#   'congo',
#   'shall',
#   'aspects',
#   'altitude',
#   'solutions',
#   'soc',
#   'bull',
#   'commercial',
#   'formations',
#   'reconstruction',
#   'information',
#   'intense',
#   'permanent',
#   'cycle',
#   'colonial',
#   'government',
#   'cf',
#   'anglo',
#   'corporation',
#   'correspondent',
#   'age',
#   'appellation',
#   'london',
#   'progressive',
#   'united',
#   'plantation',
#   'stocks',
#   'time',
#   'limitation',
#   'pin',
#   'restrictions',
#   'effective',
#   'states',
#   'plants',
#   'stable',
#   'circuit',
#   'editions',
#   'aluminium',
#   'film',
#   'alfred',
#   'stock',
#   'fluctuations',
#   'arch',
#   'treaty',
#   'index',
#   'trusts',
#   'case',
#   'contracting',
#   'initial',
#   'wagons',
#   'roosevelt',
#   'patrons',
#   'trains',
#   'high',
#   'james'],
#  ['international',
#   'congo',
#   'aspects',
#   'reconstruction',
#   'mass',
#   'solutions',
#   'anglo',
#   'information',
#   'roosevelt',
#   'soc',
#   'permanent',
#   'film',
#   'formations',
#   'intense',
#   'palestine',
#   'cf',
#   'altitude',
#   'colonial',
#   'arch',
#   'cycle',
#   'commercial',
#   'bull',
#   'correspondent',
#   'age',
#   'effective',
#   'william',
#   'stocks',
#   'arthur',
#   'trusts',
#   'alaska',
#   'progressive',
#   'hostile',
#   'wilson',
#   'stable',
#   'patrons',
#   'aluminium',
#   'shakespeare',
#   'limitation',
#   'nazis',
#   'editions',
#   'contacts',
#   'changes',
#   'alfred',
#   'corporation',
#   'initial',
#   'london',
#   'restrictions',
#   'incidents',
#   'roses',
#   'circuit',
#   'block',
#   'index',
#   'wagons',
#   'james',
#   'post'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'information',
#   'reconstruction',
#   'soc',
#   'film',
#   'cycle',
#   'formations',
#   'anglo',
#   'bull',
#   'permanent',
#   'age',
#   'intense',
#   'colonial',
#   'commercial',
#   'altitude',
#   'correspondent',
#   'wagons',
#   'effective',
#   'palestine',
#   'progressive',
#   'circuit',
#   'cf',
#   'infection',
#   'stocks',
#   'stable',
#   'limitation',
#   'trains',
#   'arch',
#   'editions',
#   'contacts',
#   'post',
#   'intelligible',
#   'aluminium',
#   'plants',
#   'hostile',
#   'sand',
#   'index',
#   'incidents',
#   'initial',
#   'alfred',
#   'london',
#   'contemplation',
#   'attitudes',
#   'restrictions',
#   'plantation',
#   'structures',
#   'changes',
#   'stock',
#   'james',
#   'musical',
#   'time',
#   'william',
#   'immigration',
#   'education'],
#  ['international',
#   'congo',
#   'solutions',
#   'aspects',
#   'soc',
#   'reconstruction',
#   'information',
#   'altitude',
#   'film',
#   'anglo',
#   'cycle',
#   'bull',
#   'circuit',
#   'intense',
#   'correspondent',
#   'permanent',
#   'formations',
#   'colonial',
#   'commercial',
#   'plants',
#   'age',
#   'progressive',
#   'effective',
#   'infection',
#   'cf',
#   'stable',
#   'ferry',
#   'alfred',
#   'editions',
#   'marks',
#   'limitation',
#   'stocks',
#   'initial',
#   'pin',
#   'structures',
#   'plantation',
#   'arch',
#   'london',
#   'aluminium',
#   'contacts',
#   'hostile',
#   'trains',
#   'incidents',
#   'palestine',
#   'wagons',
#   'index',
#   'james',
#   'support',
#   'attitudes',
#   'test',
#   'roosevelt',
#   'patrons',
#   'post',
#   'changes',
#   'intelligible'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'soc',
#   'altitude',
#   'reconstruction',
#   'information',
#   'film',
#   'cycle',
#   'bull',
#   'marshall',
#   'intense',
#   'permanent',
#   'commercial',
#   'correspondent',
#   'formations',
#   'anglo',
#   'palestine',
#   'london',
#   'progressive',
#   'test',
#   'age',
#   'circuit',
#   'colonial',
#   'effective',
#   'cf',
#   'stable',
#   'tests',
#   'structures',
#   'aluminium',
#   'plants',
#   'index',
#   'initial',
#   'trains',
#   'infection',
#   'contacts',
#   'james',
#   'restrictions',
#   'editions',
#   'stocks',
#   'calcium',
#   'roosevelt',
#   'hostile',
#   'changes',
#   'post',
#   'limitation',
#   'time',
#   'alfred',
#   'attitudes',
#   'immigration',
#   'support',
#   'plantation',
#   'fluctuations',
#   'wagons',
#   'william',
#   'pin',
#   'incidents',
#   'standard',
#   'arch'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'solutions',
#   'soc',
#   'cycle',
#   'altitude',
#   'film',
#   'commercial',
#   'formations',
#   'permanent',
#   'intense',
#   'structures',
#   'reconstruction',
#   'correspondent',
#   'age',
#   'cf',
#   'colonial',
#   'anglo',
#   'bull',
#   'london',
#   'progressive',
#   'circuit',
#   'time',
#   'test',
#   'effective',
#   'contacts',
#   'infection',
#   'musical',
#   'marshall',
#   'immigration',
#   'stable',
#   'arch',
#   'limitation',
#   'initial',
#   'plants',
#   'wagons',
#   'trains',
#   'post',
#   'tests',
#   'index',
#   'irrigation',
#   'plantation',
#   'soil',
#   'attitudes',
#   'support',
#   'changes',
#   'palestine',
#   'editions',
#   'alfred',
#   'restrictions',
#   'stocks',
#   'hostile',
#   'site',
#   'fluctuations',
#   'use',
#   'calcium',
#   'case',
#   'report',
#   'university',
#   'education',
#   'aluminium',
#   'james'],
#  ['international',
#   'congo',
#   'aspects',
#   'soc',
#   'solutions',
#   'information',
#   'altitude',
#   'cycle',
#   'commercial',
#   'permanent',
#   'formations',
#   'intense',
#   'film',
#   'reconstruction',
#   'test',
#   'bull',
#   'age',
#   'correspondent',
#   'structures',
#   'progressive',
#   'cf',
#   'circuit',
#   'london',
#   'colonial',
#   'anglo',
#   'effective',
#   'infection',
#   'arch',
#   'time',
#   'law',
#   'plants',
#   'index',
#   'tests',
#   'post',
#   'limitation',
#   'stable',
#   'immigration',
#   'initial',
#   'contacts',
#   'aluminium',
#   'marshall',
#   'identification',
#   'editions',
#   'changes',
#   'standard',
#   'university',
#   'irrigation',
#   'attitudes',
#   'plantation',
#   'education',
#   'support',
#   'case',
#   'fluctuations',
#   'calcium',
#   'james',
#   'stocks',
#   'restrictions',
#   'arthur',
#   'mac',
#   'hostile',
#   'report',
#   'pin'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'information',
#   'soc',
#   'arch',
#   'cycle',
#   'altitude',
#   'film',
#   'commercial',
#   'bull',
#   'age',
#   'permanent',
#   'intense',
#   'infection',
#   'formations',
#   'correspondent',
#   'structures',
#   'london',
#   'anglo',
#   'law',
#   'test',
#   'reconstruction',
#   'circuit',
#   'plants',
#   'progressive',
#   'index',
#   'cf',
#   'tests',
#   'effective',
#   'time',
#   'stable',
#   'limitation',
#   'colonial',
#   'initial',
#   'contacts',
#   'arthur',
#   'case',
#   'support',
#   'editions',
#   'mac',
#   'attitudes',
#   'post',
#   'immigration',
#   'plantation',
#   'irrigation',
#   'fluctuations',
#   'education',
#   'standard',
#   'report',
#   'university',
#   'changes',
#   'cases',
#   'appellation',
#   'identification',
#   'restrictions',
#   'marshall',
#   'calcium',
#   'hostile',
#   'incidents',
#   'stage',
#   'aluminium',
#   'american',
#   'james',
#   'use'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'soc',
#   'information',
#   'cycle',
#   'altitude',
#   'commercial',
#   'permanent',
#   'bull',
#   'film',
#   'formations',
#   'correspondent',
#   'structures',
#   'arch',
#   'test',
#   'index',
#   'reconstruction',
#   'intense',
#   'age',
#   'cf',
#   'progressive',
#   'plants',
#   'london',
#   'circuit',
#   'law',
#   'post',
#   'stable',
#   'effective',
#   'anglo',
#   'initial',
#   'plantation',
#   'tests',
#   'limitation',
#   'irrigation',
#   'stocks',
#   'time',
#   'colonial',
#   'infection',
#   'contacts',
#   'changes',
#   'case',
#   'aluminium',
#   'attitudes',
#   'fluctuations',
#   'standard',
#   'james',
#   'report',
#   'editions',
#   'restrictions',
#   'stock',
#   'calcium',
#   'mac',
#   'support',
#   'identification',
#   'university',
#   'stage',
#   'alfred',
#   'dominant',
#   'intellect',
#   'corrosion',
#   'education',
#   'pin'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'information',
#   'soc',
#   'cycle',
#   'bull',
#   'commercial',
#   'altitude',
#   'structures',
#   'permanent',
#   'arch',
#   'circuit',
#   'formations',
#   'correspondent',
#   'film',
#   'london',
#   'cf',
#   'intense',
#   'reconstruction',
#   'colonial',
#   'progressive',
#   'anglo',
#   'age',
#   'effective',
#   'attitudes',
#   'contacts',
#   'index',
#   'case',
#   'test',
#   'infection',
#   'law',
#   'stable',
#   'irrigation',
#   'immigration',
#   'post',
#   'limitation',
#   'initial',
#   'time',
#   'fluctuations',
#   'tests',
#   'stocks',
#   'restrictions',
#   'mac',
#   'james',
#   'plants',
#   'editions',
#   'identification',
#   'wagons',
#   'education',
#   'plantation',
#   'university',
#   'aluminium',
#   'calcium',
#   'report',
#   'trains',
#   'support',
#   'location',
#   'standard',
#   'hostile',
#   'alfred',
#   'american',
#   'changes',
#   'cases'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'solutions',
#   'soc',
#   'altitude',
#   'cycle',
#   'bull',
#   'test',
#   'film',
#   'structures',
#   'commercial',
#   'formations',
#   'permanent',
#   'cf',
#   'london',
#   'correspondent',
#   'tests',
#   'intense',
#   'infection',
#   'age',
#   'progressive',
#   'arch',
#   'index',
#   'plants',
#   'anglo',
#   'reconstruction',
#   'contacts',
#   'time',
#   'effective',
#   'attitudes',
#   'colonial',
#   'post',
#   'fluctuations',
#   'stable',
#   'limitation',
#   'law',
#   'circuit',
#   'initial',
#   'aluminium',
#   'irrigation',
#   'stocks',
#   'case',
#   'report',
#   'education',
#   'support',
#   'plantation',
#   'editions',
#   'standard',
#   'textile',
#   'immigration',
#   'use',
#   'university',
#   'james',
#   'alfred',
#   'version',
#   'identification',
#   'trains',
#   'stock',
#   'american',
#   'restrictions',
#   'william',
#   'stage',
#   'hostile',
#   'changes',
#   'incidents'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'solutions',
#   'soc',
#   'structures',
#   'cycle',
#   'commercial',
#   'bull',
#   'film',
#   'london',
#   'permanent',
#   'altitude',
#   'age',
#   'intense',
#   'correspondent',
#   'test',
#   'cf',
#   'progressive',
#   'formations',
#   'circuit',
#   'contacts',
#   'arch',
#   'wilson',
#   'anglo',
#   'law',
#   'aluminium',
#   'index',
#   'time',
#   'case',
#   'infection',
#   'limitation',
#   'tests',
#   'plantation',
#   'post',
#   'lloyd',
#   'reconstruction',
#   'plants',
#   'stable',
#   'calcium',
#   'effective',
#   'colonial',
#   'attitudes',
#   'initial',
#   'editions',
#   'education',
#   'irrigation',
#   'cases',
#   'identification',
#   'university',
#   'fluctuations',
#   'intelligible',
#   'support',
#   'patient',
#   'william',
#   'trains',
#   'report',
#   'version',
#   'stocks',
#   'james',
#   'circuits',
#   'standard',
#   'american',
#   'alfred',
#   'mac',
#   'use',
#   'changes',
#   'med',
#   'restrictions',
#   'hostile',
#   'promotion',
#   'incidents',
#   'wagons',
#   'ml',
#   'united'],
#  ['international',
#   'congo',
#   'aspects',
#   'solutions',
#   'information',
#   'soc',
#   'altitude',
#   'structures',
#   'film',
#   'cycle',
#   'bull',
#   'commercial',
#   'formations',
#   'permanent',
#   'age',
#   'correspondent',
#   'test',
#   'intense',
#   'progressive',
#   'cf',
#   'contacts',
#   'circuit',
#   'london',
#   'index',
#   'stable',
#   'post',
#   'reconstruction',
#   'effective',
#   'tests',
#   'limitation',
#   'attitudes',
#   'arch',
#   'anglo',
#   'initial',
#   'infection',
#   'editions',
#   'fluctuations',
#   'irrigation',
#   'time',
#   'colonial',
#   'plantation',
#   'plants',
#   'law',
#   'textile',
#   'standard',
#   'aluminium',
#   'university',
#   'support',
#   'education',
#   'calcium',
#   'rec',
#   'qualification',
#   'stocks',
#   'immigration',
#   'promotion',
#   'version',
#   'identification',
#   'case',
#   'cases',
#   'patrons',
#   'report',
#   'patient',
#   'incidents',
#   'cycles',
#   'uranium',
#   'alfred',
#   'radiation',
#   'hostile',
#   'stock',
#   'restrictions',
#   'stage'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'solutions',
#   'structures',
#   'soc',
#   'cycle',
#   'uranium',
#   'commercial',
#   'film',
#   'permanent',
#   'cf',
#   'altitude',
#   'bull',
#   'correspondent',
#   'formations',
#   'london',
#   'progressive',
#   'intense',
#   'age',
#   'circuit',
#   'corrosion',
#   'contacts',
#   'test',
#   'effective',
#   'index',
#   'aluminium',
#   'post',
#   'tests',
#   'anglo',
#   'stable',
#   'editions',
#   'limitation',
#   'reconstruction',
#   'time',
#   'arch',
#   'law',
#   'irrigation',
#   'education',
#   'stocks',
#   'qualification',
#   'restrictions',
#   'initial',
#   'attitudes',
#   'plantation',
#   'version',
#   'infection',
#   'identification',
#   'plants',
#   'university',
#   'james',
#   'changes',
#   'colonial',
#   'discrimination',
#   'standard',
#   'fluctuations',
#   'report',
#   'alfred',
#   'stage',
#   'incidents',
#   'case',
#   'rites',
#   'chicago',
#   'promotion',
#   'calcium',
#   'trains',
#   'rec',
#   'hostile',
#   'cases',
#   'appellation',
#   'ml',
#   'support',
#   'william'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'solutions',
#   'structures',
#   'soc',
#   'cycle',
#   'formations',
#   'film',
#   'altitude',
#   'circuit',
#   'commercial',
#   'permanent',
#   'cf',
#   'bull',
#   'correspondent',
#   'progressive',
#   'age',
#   'test',
#   'contacts',
#   'intense',
#   'limitation',
#   'index',
#   'london',
#   'law',
#   'post',
#   'arch',
#   'effective',
#   'stable',
#   'aluminium',
#   'attitudes',
#   'initial',
#   'ml',
#   'infection',
#   'anglo',
#   'irrigation',
#   'uranium',
#   'calcium',
#   'colonial',
#   'time',
#   'reconstruction',
#   'tests',
#   'stocks',
#   'promotion',
#   'restrictions',
#   'plants',
#   'case',
#   'editions',
#   'education',
#   'fluctuations',
#   'identification',
#   'circuits',
#   'standard',
#   'support',
#   'cycles',
#   'immigration',
#   'incidents',
#   'report',
#   'discrimination',
#   'qualification',
#   'version',
#   'plantation',
#   'university',
#   'stock',
#   'cases',
#   'trains',
#   'stage',
#   'hostile',
#   'alfred',
#   'patient'],
#  ['international',
#   'congo',
#   'aspects',
#   'structures',
#   'information',
#   'solutions',
#   'cycle',
#   'soc',
#   'commercial',
#   'formations',
#   'cf',
#   'bull',
#   'permanent',
#   'film',
#   'correspondent',
#   'age',
#   'progressive',
#   'altitude',
#   'arch',
#   'circuit',
#   'test',
#   'london',
#   'contacts',
#   'intense',
#   'limitation',
#   'uranium',
#   'attitudes',
#   'index',
#   'effective',
#   'fluctuations',
#   'stable',
#   'post',
#   'aluminium',
#   'anglo',
#   'infection',
#   'colonial',
#   'initial',
#   'promotion',
#   'stocks',
#   'tests',
#   'editions',
#   'reconstruction',
#   'restrictions',
#   'time',
#   'ml',
#   'circuits',
#   'university',
#   'identification',
#   'law',
#   'discrimination',
#   'changes',
#   'education',
#   'support',
#   'calcium',
#   'qualification',
#   'version',
#   'alfred',
#   'irrigation',
#   'case',
#   'report',
#   'site',
#   'plants',
#   'james',
#   'hostile',
#   'incidents',
#   'standard',
#   'stock',
#   'cycles',
#   'patient',
#   'textile',
#   'cases',
#   'dominant',
#   'plantation',
#   'rites'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'structures',
#   'solutions',
#   'cycle',
#   'soc',
#   'film',
#   'commercial',
#   'test',
#   'permanent',
#   'age',
#   'cf',
#   'bull',
#   'altitude',
#   'formations',
#   'correspondent',
#   'contacts',
#   'progressive',
#   'index',
#   'london',
#   'intense',
#   'circuit',
#   'attitudes',
#   'promotion',
#   'tests',
#   'editions',
#   'arch',
#   'effective',
#   'limitation',
#   'post',
#   'stable',
#   'uranium',
#   'time',
#   'identification',
#   'stocks',
#   'ml',
#   'initial',
#   'case',
#   'aluminium',
#   'law',
#   'infection',
#   'qualification',
#   'anglo',
#   'textile',
#   'restrictions',
#   'report',
#   'calcium',
#   'education',
#   'fluctuations',
#   'reconstruction',
#   'mac',
#   'colonial',
#   'university',
#   'version',
#   'irrigation',
#   'incidents',
#   'discrimination',
#   'support',
#   'patient',
#   'plantation',
#   'cases',
#   'standard',
#   'mental',
#   'plants',
#   'circuits',
#   'changes',
#   'hostile',
#   'alfred'],
#  ['international',
#   'congo',
#   'aspects',
#   'information',
#   'structures',
#   'solutions',
#   'soc',
#   'cycle',
#   'film',
#   'commercial',
#   'permanent',
#   'altitude',
#   'age',
#   'bull',
#   'promotion',
#   'correspondent',
#   'formations',
#   'cf',
#   'aluminium',
#   'contacts',
#   'london',
#   'attitudes',
#   'progressive',
#   'circuit',
#   'test',
#   'intense',
#   'arch',
#   'index',
#   'stable',
#   'ml',
#   'editions',
#   'irrigation',
#   'limitation',
#   'post',
#   'education',
#   'effective',
#   'tests',
#   'colonial',
#   'identification',
#   'initial',
#   'support',
#   'fluctuations',
#   'version',
#   'qualification',
#   'stocks',
#   'anglo',
#   'university',
#   'time',
#   'patient',
#   'restrictions',
#   'reconstruction',
#   'circuits',
#   'stage',
#   'textile',
#   'infection',
#   'standard',
#   'uranium',
#   'james',
#   'incidents',
#   'calcium',
#   'site',
#   'discrimination',
#   'report',
#   'hostile',
#   'rites',
#   'cycles',
#   'plantation'],
#  ['international',
#   'information',
#   'congo',
#   'aspects',
#   'structures',
#   'solutions',
#   'cycle',
#   'film',
#   'soc',
#   'commercial',
#   'cf',
#   'age',
#   'permanent',
#   'bull',
#   'correspondent',
#   'contacts',
#   'attitudes',
#   'test',
#   'london',
#   'promotion',
#   'progressive',
#   'formations',
#   'altitude',
#   'education',
#   'index',
#   'effective',
#   'intense',
#   'ml',
#   'circuit',
#   'tests',
#   'limitation',
#   'initial',
#   'stable',
#   'post',
#   'editions',
#   'anglo',
#   'aluminium',
#   'time',
#   'identification',
#   'uranium',
#   'fluctuations',
#   'qualification',
#   'colonial',
#   'stocks',
#   'arch',
#   'restrictions',
#   'version',
#   'support',
#   'university',
#   'stage',
#   'reconstruction',
#   'incidents',
#   'patrons',
#   'irrigation',
#   'law',
#   'case',
#   'hostile',
#   'report',
#   'textile',
#   'doc',
#   'circuits',
#   'rec',
#   'standard',
#   'infection',
#   'cycles',
#   'discrimination',
#   'philippines'],
#  ['international',
#   'information',
#   'aspects',
#   'structures',
#   'congo',
#   'solutions',
#   'cycle',
#   'soc',
#   'commercial',
#   'permanent',
#   'film',
#   'age',
#   'cf',
#   'promotion',
#   'attitudes',
#   'bull',
#   'london',
#   'correspondent',
#   'contacts',
#   'circuit',
#   'index',
#   'progressive',
#   'arch',
#   'test',
#   'intense',
#   'education',
#   'formations',
#   'altitude',
#   'effective',
#   'version',
#   'ml',
#   'stable',
#   'post',
#   'initial',
#   'editions',
#   'identification',
#   'limitation',
#   'university',
#   'tests',
#   'law',
#   'time',
#   'qualification',
#   'irrigation',
#   'circuits',
#   'anglo',
#   'aluminium',
#   'case',
#   'restrictions',
#   'textile',
#   'fluctuations',
#   'patient',
#   'stage',
#   'colonial',
#   'stocks',
#   'reconstruction',
#   'support',
#   'james',
#   'report',
#   'immigration',
#   'uranium',
#   'plantation',
#   'site',
#   'william',
#   'cycles',
#   'alfred',
#   'discrimination',
#   'standard',
#   'hostile',
#   'incidents',
#   'notices',
#   'changes'],
#  ['international',
#   'information',
#   'aspects',
#   'structures',
#   'congo',
#   'solutions',
#   'cycle',
#   'commercial',
#   'london',
#   'age',
#   'soc',
#   'cf',
#   'permanent',
#   'index',
#   'film',
#   'bull',
#   'promotion',
#   'contacts',
#   'attitudes',
#   'correspondent',
#   'progressive',
#   'circuit',
#   'formations',
#   'education',
#   'altitude',
#   'test',
#   'editions',
#   'ml',
#   'intense',
#   'stable',
#   'limitation',
#   'aluminium',
# ...
#   'christian',
#   'formations',
#   'support',
#   'patients',
#   'attitudes',
#   'interaction',
#   'education',
#   'ere',
#   'contacts',
#   'london',
#   'qualification',
#   'management',
#   'cambridge',
#   'occurrence',
#   'correspondent',
#   'reconstruction',
#   'progressive',
#   'index',
#   'effective',
#   'stable',
#   'illustration',
#   'performance',
#   'james',
#   'initial',
#   'colonial',
#   'performances',
#   'alternative',
#   'discrimination',
#   'time',
#   'issues',
#   'peter',
#   'football',
#   'formulation',
#   'test',
#   'interactions',
#   'rites',
#   'oxford',
#   'william',
#   'intense',
#   'anglo',
#   'configuration',
#   'patrick',
#   'leader',
#   'francis',
#   'case',
#   'motivation',
#   'soc',
#   'dominant',
#   'gains',
#   'lectures',
#   'stock',
#   'nigeria',
#   'appropriation',
#   'messages',
#   'standard',
#   'musical',
#   'migration',
#   'codes',
#   'sports',
#   'tests',
#   'jacob',
#   'implications',
#   'report',
#   'humour',
#   'limitation',
#   'stage',
#   'stocks',
#   'mental',
#   'world',
#   'law',
#   'restrictions',
#   'benjamin',
#   'dollar',
#   'alfred',
#   'development',
#   'studies',
#   'mail',
#   'massive',
#   'strict'],
#  ['information',
#   'international',
#   'structures',
#   'aspects',
#   'site',
#   'film',
#   'impact',
#   'cycle',
#   'version',
#   'promotion',
#   'cf',
#   'sites',
#   'solutions',
#   'internet',
#   'identification',
#   'congo',
#   'fiction',
#   'commercial',
#   'university',
#   'immigration',
#   'patient',
#   'age',
#   'post',
#   'christian',
#   'editions',
#   'formations',
#   'permanent',
#   'support',
#   'contacts',
#   'interaction',
#   'reconstruction',
#   'sport',
#   'london',
#   'patients',
#   'attitudes',
#   'correspondent',
#   'cambridge',
#   'qualification',
#   'occurrence',
#   'colonial',
#   'effective',
#   'progressive',
#   'illustration',
#   'index',
#   'performance',
#   'stable',
#   'education',
#   'discrimination',
#   'initial',
#   'time',
#   'issues',
#   'management',
#   'james',
#   'alternative',
#   'oxford',
#   'rec',
#   'case',
#   'performances',
#   'interactions',
#   'intense',
#   'peter',
#   'formulation',
#   'test',
#   'anglo',
#   'william',
#   'leader',
#   'patrick',
#   'configuration',
#   'migration',
#   'dominant',
#   'lectures',
#   'appropriation',
#   'rites',
#   'report',
#   'jacob',
#   'stock',
#   'gains',
#   'francis',
#   'standard',
#   'law',
#   'restrictions',
#   'messages',
#   'motivation',
#   'limitation',
#   'mail',
#   'humour',
#   'alfred',
#   'world',
#   'development',
#   'codes',
#   'implications',
#   'mental',
#   'history',
#   'bull'],
#  ['information',
#   'international',
#   'structures',
#   'aspects',
#   'site',
#   'film',
#   'internet',
#   'impact',
#   'version',
#   'cycle',
#   'promotion',
#   'cf',
#   'sites',
#   'solutions',
#   'identification',
#   'fiction',
#   'editions',
#   'university',
#   'immigration',
#   'congo',
#   'commercial',
#   'post',
#   'christian',
#   'patient',
#   'age',
#   'support',
#   'cambridge',
#   'attitudes',
#   'interaction',
#   'formations',
#   'london',
#   'permanent',
#   'contacts',
#   'sport',
#   'patients',
#   'occurrence',
#   'correspondent',
#   'qualification',
#   'progressive',
#   'reconstruction',
#   'effective',
#   'colonial',
#   'initial',
#   'illustration',
#   'management',
#   'discrimination',
#   'stable',
#   'performance',
#   'alternative',
#   'performances',
#   'education',
#   'oxford',
#   'rites',
#   'issues',
#   'james',
#   'index',
#   'william',
#   'peter',
#   'formulation',
#   'intense',
#   'interactions',
#   'patrick',
#   'configuration',
#   'test',
#   'appropriation',
#   'anglo',
#   'time',
#   'humour',
#   'dominant',
#   'motivation',
#   'lectures',
#   'benjamin',
#   'stock',
#   'leader',
#   'mail',
#   'francis',
#   'gains',
#   'migration',
#   'case',
#   'musical',
#   'messages',
#   'world',
#   'jacob',
#   'codes',
#   'standard',
#   'alfred',
#   'tests',
#   'limitation',
#   'report',
#   'restrictions',
#   'law',
#   'implications',
#   'history',
#   'studies',
#   'adolescents',
#   'web',
#   'development',
#   'strict',
#   'massive',
#   'leaders',
#   'sports',
#   'eds'],
#  ['information',
#   'international',
#   'structures',
#   'aspects',
#   'film',
#   'site',
#   'internet',
#   'impact',
#   'version',
#   'congo',
#   'cycle',
#   'sites',
#   'promotion',
#   'cf',
#   'solutions',
#   'identification',
#   'immigration',
#   'fiction',
#   'university',
#   'post',
#   'patient',
#   'editions',
#   'commercial',
#   'support',
#   'patients',
#   'christian',
#   'sport',
#   'interaction',
#   'occurrence',
#   'cambridge',
#   'formations',
#   'permanent',
#   'age',
#   'contacts',
#   'colonial',
#   'qualification',
#   'attitudes',
#   'correspondent',
#   'london',
#   'performance',
#   'reconstruction',
#   'illustration',
#   'progressive',
#   'index',
#   'effective',
#   'discrimination',
#   'issues',
#   'stable',
#   'alternative',
#   'initial',
#   'management',
#   'performances',
#   'oxford',
#   'test',
#   'james',
#   'configuration',
#   'interactions',
#   'rites',
#   'formulation',
#   'education',
#   'peter',
#   'intense',
#   'appropriation',
#   'william',
#   'time',
#   'stock',
#   'web',
#   'leader',
#   'anglo',
#   'francis',
#   'patrick',
#   'mail',
#   'dominant',
#   'lectures',
#   'motivation',
#   'case',
#   'migration',
#   'codes',
#   'jacob',
#   'standard',
#   'report',
#   'messages',
#   'limitation',
#   'rec',
#   'benjamin',
#   'tests',
#   'chicago',
#   'implications',
#   'humour',
#   'world',
#   'musical',
#   'gains',
#   'alfred',
#   'law',
#   'format',
#   'adolescents',
#   'restrictions',
#   'leaders',
#   'mental',
#   'strict',
#   'studies',
#   'festival',
#   'massive',
#   'stocks'],
#  ['information',
#   'international',
#   'structures',
#   'site',
#   'aspects',
#   'film',
#   'impact',
#   'internet',
#   'version',
#   'cycle',
#   'sites',
#   'promotion',
#   'solutions',
#   'identification',
#   'patient',
#   'patients',
#   'fiction',
#   'cf',
#   'immigration',
#   'congo',
#   'post',
#   'university',
#   'sport',
#   'support',
#   'editions',
#   'commercial',
#   'management',
#   'performance',
#   'age',
#   'christian',
#   'formations',
#   'interaction',
#   'attitudes',
#   'occurrence',
#   'contacts',
#   'permanent',
#   'cambridge',
#   'correspondent',
#   'progressive',
#   'london',
#   'reconstruction',
#   'discrimination',
#   'illustration',
#   'index',
#   'qualification',
#   'effective',
#   'performances',
#   'colonial',
#   'initial',
#   'alternative',
#   'issues',
#   'web',
#   'oxford',
#   'interactions',
#   'test',
#   'configuration',
#   'stable',
#   'rec',
#   'education',
#   'rites',
#   'intense',
#   'time',
#   'formulation',
#   'appropriation',
#   'messages',
#   'peter',
#   'mail',
#   'patrick',
#   'migration',
#   'james',
#   'standard',
#   'dominant',
#   'lectures',
#   'motivation',
#   'leader',
#   'case',
#   'anglo',
#   'william',
#   'francis',
#   'jacob',
#   'limitation',
#   'world',
#   'football',
#   'stock',
#   'report',
#   'marketing',
#   'alfred',
#   'massive',
#   'codes',
#   'sports',
#   'bush',
#   'humour',
#   'format',
#   'tests',
#   'musical',
#   'implications',
#   'benjamin',
#   'gains',
#   'supports',
#   'adolescents',
#   'restrictions',
#   'strict',
#   'mental',
#   'law'],
#  ['information',
#   'international',
#   'structures',
#   'site',
#   'aspects',
#   'film',
#   'impact',
#   'version',
#   'internet',
#   'sites',
#   'cycle',
#   'promotion',
#   'patient',
#   'congo',
#   'identification',
#   'solutions',
#   'cf',
#   'patients',
#   'immigration',
#   'post',
#   'fiction',
#   'university',
#   'editions',
#   'performance',
#   'christian',
#   'support',
#   'formations',
#   'commercial',
#   'interaction',
#   'management',
#   'sport',
#   'occurrence',
#   'age',
#   'permanent',
#   'attitudes',
#   'contacts',
#   'test',
#   'reconstruction',
#   'cambridge',
#   'london',
#   'configuration',
#   'illustration',
#   'qualification',
#   'correspondent',
#   'discrimination',
#   'interactions',
#   'progressive',
#   'alternative',
#   'performances',
#   'colonial',
#   'oxford',
#   'issues',
#   'effective',
#   'stable',
#   'education',
#   'initial',
#   'index',
#   'peter',
#   'web',
#   'james',
#   'motivation',
#   'standard',
#   'patrick',
#   'bush',
#   'intense',
#   'formulation',
#   'lectures',
#   'time',
#   'stock',
#   'tests',
#   'rites',
#   'case',
#   'anglo',
#   'william',
#   'francis',
#   'migration',
#   'appropriation',
#   'infection',
#   'jacob',
#   'dominant',
#   'leader',
#   'messages',
#   'massive',
#   'mail',
#   'musical',
#   'codes',
#   'palestine',
#   'report',
#   'alfred',
#   'format',
#   'world',
#   'limitation',
#   'humour',
#   'football',
#   'arch',
#   'implications',
#   'adolescents',
#   'stocks',
#   'benjamin',
#   'studies',
#   'stage',
#   'sports',
#   'michael',
#   'leaders',
#   'restrictions',
#   'supports',
#   'participant',
#   'nigeria'],
#  ['information',
#   'international',
#   'structures',
#   'site',
#   'aspects',
#   'film',
#   'impact',
#   'patient',
#   'version',
#   'cycle',
#   'internet',
#   'patients',
#   'promotion',
#   'sites',
#   'congo',
#   'immigration',
#   'identification',
#   'solutions',
#   'cf',
#   'fiction',
#   'university',
#   'post',
#   'management',
#   'performance',
#   'christian',
#   'editions',
#   'discrimination',
#   'support',
#   'sport',
#   'commercial',
#   'occurrence',
#   'formations',
#   'interaction',
#   'test',
#   'cambridge',
#   'permanent',
#   'colonial',
#   'attitudes',
#   'configuration',
#   'contacts',
#   'reconstruction',
#   'age',
#   'performances',
#   'bush',
#   'correspondent',
#   'index',
#   'illustration',
#   'interactions',
#   'london',
#   'effective',
#   'progressive',
#   'issues',
#   'qualification',
#   'oxford',
#   'alternative',
#   'initial',
#   'stable',
#   'peter',
#   'web',
#   'james',
#   'patrick',
#   'standard',
#   'william',
#   'intense',
#   'tests',
#   'formulation',
#   'format',
#   'case',
#   'anglo',
#   'time',
#   'motivation',
#   'messages',
#   'lectures',
#   'leader',
#   'education',
#   'francis',
#   'appropriation',
#   'migration',
#   'dominant',
#   'mail',
#   'codes',
#   'massive',
#   'alfred',
#   'jacob',
#   'rites',
#   'report',
#   'mental',
#   'adolescents',
#   'benjamin',
#   'michael',
#   'world',
#   'humour',
#   'stock',
#   'restrictions',
#   'arthur',
#   'palestine',
#   'gains',
#   'stage',
#   'versions',
#   'implications',
#   'stress',
#   'leaders',
#   'studies',
#   'limitation',
#   'development',
#   'connexion',
#   'sand'],
#  ['information',
#   'international',
#   'structures',
#   'site',
#   'aspects',
#   'patient',
#   'impact',
#   'film',
#   'version',
#   'internet',
#   'patients',
#   'cycle',
#   'promotion',
#   'sites',
#   'congo',
#   'identification',
#   'solutions',
#   'immigration',
#   'cf',
#   'post',
#   'university',
#   'fiction',
#   'performance',
#   'editions',
#   'test',
#   'support',
#   'sport',
#   'christian',
#   'management',
#   'commercial',
#   'formations',
#   'colonial',
#   'interaction',
#   'contacts',
#   'configuration',
#   'cambridge',
#   'performances',
#   'occurrence',
#   'permanent',
#   'discrimination',
#   'attitudes',
#   'age',
#   'reconstruction',
#   'illustration',
#   'london',
#   'interactions',
#   'progressive',
#   'correspondent',
#   'web',
#   'issues',
#   'index',
#   'alternative',
#   'stable',
#   'peter',
#   'oxford',
#   'standard',
#   'initial',
#   'qualification',
#   'effective',
#   'tests',
#   'patrick',
#   'migration',
#   'james',
#   'time',
#   'motivation',
#   'intense',
#   'formulation',
#   'education',
#   'messages',
#   'case',
#   'format',
#   'william',
#   'lectures',
#   'jacob',
#   'adolescents',
#   'rites',
#   'leader',
#   'appropriation',
#   'marketing',
#   'francis',
#   'dominant',
#   'windows',
#   'world',
#   'anglo',
#   'report',
#   'mail',
#   'stress',
#   'codes',
#   'menu',
#   'gains',
#   'bush',
#   'massive',
#   'alfred',
#   'leaders',
#   'michael',
#   'benjamin',
#   'versions',
#   'palestine',
#   'implications',
#   'mental',
#   'humour',
#   'musical',
#   'participant',
#   'studies',
#   'sports',
#   'stock',
#   'limitation',
#   'restrictions',
#   'posture',
#   'development',
#   'history',
#   'cognitive',
#   'american',
#   'questionnaire',
#   'research',
#   'soc',
#   'connexion'],
#  ['information',
#   'international',
#   'structures',
#   'site',
#   'aspects',
#   'film',
#   'impact',
#   'version',
#   'internet',
#   'patient',
#   'cycle',
#   'promotion',
#   'congo',
#   'identification',
#   'patients',
#   'sites',
#   'immigration',
#   'solutions',
#   'fiction',
#   'performance',
#   'post',
#   'university',
#   'management',
#   'test',
#   'cf',
#   'interaction',
#   'support',
#   'editions',
#   'colonial',
#   'discrimination',
#   'christian',
#   'commercial',
#   'attitudes',
#   'formations',
#   'occurrence',
#   'sport',
#   'cambridge',
#   'permanent',
#   'interactions',
#   'reconstruction',
#   'illustration',
#   'contacts',
#   'correspondent',
#   'motivation',
#   'configuration',
#   'issues',
#   'performances',
#   'london',
#   'age',
#   'james',
#   'index',
#   'initial',
#   'effective',
#   'stable',
#   'progressive',
#   'patrick',
#   'tests',
#   'oxford',
#   'web',
#   'alternative',
#   'time',
#   'qualification',
#   'peter',
#   'intense',
#   'william',
#   'formulation',
#   'messages',
#   'case',
#   'musical',
#   'migration',
#   'lectures',
#   'appropriation',
#   'education',
#   'jacob',
#   'standard',
#   'marketing',
#   'leader',
#   'anglo',
#   'rites',
#   'dominant',
#   'codes',
#   'format',
#   'humour',
#   'adolescents',
#   'mental',
#   'francis',
#   'questionnaire',
#   'report',
#   'alfred',
#   'world',
#   'stock',
#   'stress',
#   'benjamin',
#   'michael',
#   'studies',
#   'development',
#   'leaders',
#   'posture',
#   'stage',
#   'gains',
#   'participant',
#   'nigeria',
#   'research',
#   'cognitive',
#   'massive',
#   'implications',
#   'mail',
#   'ratio',
#   'restaurant',
#   'finance',
#   'menu',
#   'narrative',
#   'limitation',
#   'history',
#   'immigrants',
#   'palestine'],
#  ['information',
#   'international',
#   'film',
#   'site',
#   'structures',
#   'aspects',
#   'impact',
#   'version',
#   'internet',
#   'patient',
#   'patients',
#   'promotion',
#   'cycle',
#   'immigration',
#   'fiction',
#   'congo',
#   'sites',
#   'identification',
#   'solutions',
#   'performance',
#   'post',
#   'university',
#   'management',
#   'cf',
#   'support',
#   'sport',
#   'test',
#   'interaction',
#   'christian',
#   'colonial',
#   'editions',
#   'occurrence',
#   'attitudes',
#   'commercial',
#   'formations',
#   'configuration',
#   'contacts',
#   'interactions',
#   'discrimination',
#   'cambridge',
#   'permanent',
#   'web',
#   'performances',
#   'illustration',
#   'correspondent',
#   'peter',
#   'issues',
#   'age',
#   'motivation',
#   'patrick',
#   'london',
#   'reconstruction',
#   'james',
#   'initial',
#   'oxford',
#   'alternative',
#   'progressive',
#   'index',
#   'format',
#   'effective',
#   'stable',
#   'standard',
#   'tests',
#   'william',
#   'intense',
#   'leader',
#   'migration',
#   'jacob',
#   'messages',
#   'case',
#   'adolescents',
#   'lectures',
#   'codes',
#   'formulation',
#   'qualification',
#   'education',
#   'time',
#   'humour',
#   'appropriation',
#   'rites',
#   'francis',
#   'festival',
#   'dominant',
#   'anglo',
#   'mental',
#   'posture',
#   'alfred',
#   'benjamin',
#   'arthur',
#   'marketing',
#   'musical',
#   'michael',
#   'menu',
#   'questionnaire',
#   'report',
#   'adolescent',
#   'stock',
#   'studies',
#   'stress',
#   'stage',
#   'leaders',
#   'narrative',
#   'world',
#   'cognitive',
#   'restaurant',
#   'mail',
#   'gains',
#   'finance',
#   'versions',
#   'participant',
#   'history',
#   'champion',
#   'supports',
#   'circuit',
#   'massive'],
#  ['information',
#   'international',
#   'site',
#   'film',
#   'structures',
#   'aspects',
#   'impact',
#   'version',
#   'patient',
#   'internet',
#   'cycle',
#   'sites',
#   'congo',
#   'immigration',
#   'promotion',
#   'patients',
#   'performance',
#   'identification',
#   'solutions',
#   'fiction',
#   'post',
#   'university',
#   'sport',
#   'management',
#   'support',
#   'christian',
#   'test',
#   'cf',
#   'web',
#   'colonial',
#   'interaction',
#   'configuration',
#   'performances',
#   'editions',
#   'commercial',
#   'formations',
#   'occurrence',
#   'discrimination',
#   'cambridge',
#   'reconstruction',
#   'contacts',
#   'permanent',
#   'attitudes',
#   'interactions',
#   'illustration',
#   'correspondent',
#   'issues',
#   'james',
#   'peter',
#   'age',
#   'london',
#   'progressive',
#   'patrick',
#   'oxford',
#   'initial',
#   'alternative',
#   'motivation',
#   'intense',
#   'jacob',
#   'standard',
#   'tests',
#   'william',
#   'effective',
#   'index',
#   'windows',
#   'stable',
#   'messages',
#   'migration',
#   'time',
#   'leader',
#   'stress',
#   'qualification',
#   'appropriation',
#   'lectures',
#   'format',
#   'codes',
#   'formulation',
#   'palestine',
#   'case',
#   'francis',
#   'education',
#   'adolescents',
#   'humour',
#   'benjamin',
#   'football',
#   'posture',
#   'menu',
#   'anglo',
#   'sports',
#   'mental',
#   'rites',
#   'dominant',
#   'alfred',
#   'festival',
#   'report',
#   'restaurant',
#   'world',
#   'leaders',
#   'stock',
#   'versions',
#   'studies',
#   'adolescent',
#   'finance',
#   'champion',
#   'michael',
#   'massive',
#   'mail',
#   'stage',
#   'cognitive',
#   'questionnaire',
#   'gains',
#   'interface']]

# %%
words
# Out:
# [['plantations',
#   'colonial',
#   'op',
#   'boers',
#   'expansion',
#   'doses',
#   'suggestion',
#   'gain',
#   'arthur',
#   'pin',
#   'age',
#   'plate',
#   'phrases',
#   'dollars'],
#  ['op',
#   'colonial',
#   'expansion',
#   'doses',
#   'dollars',
#   'plantations',
#   'suggestion',
#   'gain',
#   'london',
#   'arthur',
#   'index',
#   'age',
#   'marks',
#   'formations'],
#  ['colonial',
#   'op',
#   'expansion',
#   'doses',
#   'boers',
#   'plantations',
#   'dollars',
#   'suggestion',
#   'marks',
#   'gain',
#   'nice',
#   'armature',
#   'courts'],
#  ['op',
#   'dollars',
#   'colonial',
#   'expansion',
#   'doses',
#   'marks',
#   'trust',
#   'plantations',
#   'suggestion'],
#  ['op',
#   'arthur',
#   'dollars',
#   'colonial',
#   'doses',
#   'expansion',
#   'gain',
#   'aspects',
#   'james',
#   'plantations'],
#  ['op',
#   'expansion',
#   'colonial',
#   'dollars',
#   'arthur',
#   'doses',
#   'anglo',
#   'gain',
#   'aluminium',
#   'marks',
#   'location',
#   'formations',
#   'club'],
#  ['op',
#   'colonial',
#   'expansion',
#   'dollars',
#   'doses',
#   'plantations',
#   'marks',
#   'aluminium',
#   'arthur',
#   'aspects',
#   'published',
#   'gain',
#   'formations',
#   'lots'],
#  ['op',
#   'colonial',
#   'dollars',
#   'formations',
#   'doses',
#   'expansion',
#   'gain',
#   'arthur',
#   'plantations',
#   'aspects',
#   'calcium',
#   'limitation',
#   'london',
#   'age',
#   'index',
#   'phrases'],
#  ['op',
#   'dollars',
#   'colonial',
#   'marks',
#   'expansion',
#   'plantations',
#   'gain',
#   'arthur',
#   'phrases',
#   'concept',
#   'aspects',
#   'doses',
#   'james',
#   'club',
#   'index',
#   'limitation'],
#  ['op',
#   'aluminium',
#   'club',
#   'aspects',
#   'expansion',
#   'phrases',
#   'age',
#   'formations',
#   'colonial',
#   'james',
#   'dollars',
#   'gain',
#   'arthur',
#   'marks',
#   'cf',
#   'nice',
#   'plantations',
#   'index'],
#  ['op',
#   'club',
#   'aspects',
#   'suggestion',
#   'colonial',
#   'expansion',
#   'doses',
#   'plantations',
#   'formations',
#   'lords',
#   'james',
#   'dollars',
#   'age',
#   'phrases',
#   'aluminium',
#   'london',
#   'calcium',
#   'anglo',
#   'index',
#   'gain'],
#  ['op',
#   'james',
#   'aspects',
#   'colonial',
#   'plantations',
#   'expansion',
#   'phrases',
#   'london',
#   'club',
#   'age',
#   'concept',
#   'dollars',
#   'aluminium',
#   'index',
#   'suggestion',
#   'doses',
#   'mental'],
#  ['op',
#   'lots',
#   'aspects',
#   'doses',
#   'club',
#   'london',
#   'colonial',
#   'dollars',
#   'expansion',
#   'william',
#   'james',
#   'arthur',
#   'phrases',
#   'age',
#   'marks',
#   'suggestion',
#   'motion',
#   'formations'],
#  ['op',
#   'club',
#   'aspects',
#   'james',
#   'phrases',
#   'london',
#   'doses',
#   'colonial',
#   'expansion',
#   'dollars',
#   'panama',
#   'plantations',
#   'marks',
#   'cycle',
#   'age',
#   'cf',
#   'index',
#   'gain',
#   'arthur',
#   'formations',
#   'concept',
#   'pin',
#   'incidents',
#   'situations'],
#  ['op',
#   'aspects',
#   'london',
#   'doses',
#   'expansion',
#   'phrases',
#   'gain',
#   'marks',
#   'age',
#   'plantations',
#   'colonial',
#   'incidents',
#   'information',
#   'index'],
#  ['offensive',
#   'anglo',
#   'marks',
#   'slave',
#   'op',
#   'expansion',
#   'formations',
#   'nice',
#   'colonial',
#   'information',
#   'hostile',
#   'grey',
#   'aspects',
#   'phrases',
#   'anti',
#   'incidents',
#   'william',
#   'arthur',
#   'edward',
#   'wilson'],
#  ['offensive',
#   'marks',
#   'capture',
#   'op',
#   'expansion',
#   'colonial',
#   'wilson',
#   'formations',
#   'taxation',
#   'dollars',
#   'anglo',
#   'aspects',
#   'phrases',
#   'stocks',
#   'hostile',
#   'drainage',
#   'gain',
#   'information',
#   'situations',
#   'lots',
#   'incidents'],
#  ['offensive',
#   'wilson',
#   'expansion',
#   'slave',
#   'formations',
#   'taxation',
#   'marks',
#   'aspects',
#   'dollars',
#   'phrases',
#   'colonial',
#   'restrictions',
#   'doses',
#   'aluminium',
#   'stocks',
#   'anti',
#   'anglo',
#   'lloyd',
#   'op',
#   'hostile',
#   'gain',
#   'information',
#   'london',
#   'situations',
#   'incidents'],
#  ['offensive',
#   'wilson',
#   'slave',
#   'expansion',
#   'colonial',
#   'aluminium',
#   'marks',
#   'lloyd',
#   'restrictions',
#   'dollars',
#   'aspects',
#   'anglo',
#   'hostile',
#   'op',
#   'information',
#   'phrases',
#   'wagon',
#   'message',
#   'capture',
#   'anti',
#   'gain',
#   'club',
#   'situations',
#   'incidents',
#   'age',
#   'daniel',
#   'arthur',
#   'formations',
#   'cycle'],
#  ['wilson',
#   'offensive',
#   'colonial',
#   'op',
#   'slave',
#   'expansion',
#   'dollars',
#   'formations',
#   'aspects',
#   'lloyd',
#   'marks',
#   'phrases',
#   'reconstruction',
#   'restrictions',
#   'aluminium',
#   'anglo',
#   'information',
#   'james',
#   'anti',
#   'limitation',
#   'hostile',
#   'william',
#   'coke',
#   'incidents',
#   'suggestion',
#   'gain',
#   'effective',
#   'stocks'],
#  ['offensive',
#   'op',
#   'wilson',
#   'aspects',
#   'colonial',
#   'concept',
#   'expansion',
#   'marks',
#   'aluminium',
#   'dollars',
#   'cycle',
#   'james',
#   'lloyd',
#   'limitation',
#   'age',
#   'doses',
#   'phrases',
#   'plantations',
#   'anglo',
#   'coke',
#   'concepts',
#   'reconstruction',
#   'formations',
#   'information',
#   'cf',
#   'restrictions',
#   'club',
#   'anti',
#   'index',
#   'london',
#   'effective',
#   'courts',
#   'law'],
#  ['op',
#   'offensive',
#   'marks',
#   'colonial',
#   'dollars',
#   'wilson',
#   'aspects',
#   'aluminium',
#   'capture',
#   'doses',
#   'lloyd',
#   'expansion',
#   'phrases',
#   'hostile',
#   'age',
#   'index',
#   'club',
#   'anglo',
#   'james',
#   'information',
#   'limitation',
#   'concept',
#   'coke',
#   'formations',
#   'reconstruction',
#   'cycle',
#   'stocks',
#   'anti',
#   'restrictions',
#   'gain',
#   'london',
#   'plantations'],
#  ['marks',
#   'lloyd',
#   'offensive',
#   'colonial',
#   'aspects',
#   'op',
#   'dollars',
#   'james',
#   'expansion',
#   'reconstruction',
#   'phrases',
#   'mark',
#   'plantations',
#   'limitation',
#   'doses',
#   'anglo',
#   'wilson',
#   'formations',
#   'cycle',
#   'london',
#   'information',
#   'index',
#   'age',
#   'anti',
#   'cf',
#   'changes',
#   'effective',
#   'concept',
#   'club',
#   'coke'],
#  ['marks',
#   'op',
#   'aspects',
#   'dollars',
#   'offensive',
#   'colonial',
#   'james',
#   'phrases',
#   'doses',
#   'index',
#   'mark',
#   'anglo',
#   'coke',
#   'reconstruction',
#   'formations',
#   'expansion',
#   'william',
#   'limitation',
#   'cf',
#   'age',
#   'wilson',
#   'cycle',
#   'concept',
#   'palestine',
#   'lots',
#   'anti',
#   'prose',
#   'effective',
#   'information',
#   'london',
#   'lloyd',
#   'plantations',
#   'lectures',
#   'hostile'],
#  ['marks',
#   'aspects',
#   'offensive',
#   'dollars',
#   'op',
#   'phrases',
#   'colonial',
#   'coke',
#   'london',
#   'index',
#   'anglo',
#   'doses',
#   'formations',
#   'wilson',
#   'cycle',
#   'expansion',
#   'concept',
#   'plantations',
#   'age',
#   'prose',
#   'effective',
#   'changes',
#   'anti',
#   'information',
#   'limitation',
#   'aluminium',
#   'stable',
#   'gain',
#   'palestine',
#   'james'],
#  ['op',
#   'aspects',
#   'dollars',
#   'colonial',
#   'offensive',
#   'doses',
#   'marks',
#   'immigration',
#   'index',
#   'london',
#   'cycle',
#   'phrases',
#   'plantations',
#   'swift',
#   'information',
#   'anglo',
#   'limitation',
#   'expansion',
#   'formations',
#   'james',
#   'anti',
#   'situations',
#   'prose',
#   'age',
#   'gain',
#   'incidents',
#   'stable',
#   'effective',
#   'calcium',
#   'changes',
#   'concept'],
#  ['op',
#   'aspects',
#   'dollars',
#   'marks',
#   'formations',
#   'age',
#   'cycle',
#   'anglo',
#   'concept',
#   'limitation',
#   'colonial',
#   'phrases',
#   'doses',
#   'expansion',
#   'london',
#   'prose',
#   'offensive',
#   'index',
#   'information',
#   'plantations',
#   'anti',
#   'rate',
#   'stable',
#   'coke',
#   'effective',
#   'gain',
#   'immigration',
#   'incidents',
#   'james',
#   'hostile',
#   'changes',
#   'arthur',
#   'concepts',
#   'courts',
#   'lots',
#   'post'],
#  ['op',
#   'aspects',
#   'dollars',
#   'doses',
#   'offensive',
#   'cycle',
#   'age',
#   'concept',
#   'colonial',
#   'phrases',
#   'index',
#   'anglo',
#   'limitation',
#   'london',
#   'vaccination',
#   'formations',
#   'expansion',
#   'information',
#   'law',
#   'rate',
#   'prose',
#   'marks',
#   'anti',
#   'plantations',
#   'cf',
#   'james',
#   'irrigation',
#   'gain',
#   'courts',
#   'situations',
#   'effective',
#   'stable',
#   'post',
#   'concepts'],
#  ['aspects',
#   'op',
#   'dollars',
#   'colonial',
#   'doses',
#   'index',
#   'limitation',
#   'information',
#   'formations',
#   'plantations',
#   'age',
#   'phrases',
#   'london',
#   'cycle',
#   'vaccination',
#   'marks',
#   'anti',
#   'expansion',
#   'anglo',
#   'concept',
#   'situations',
#   'offensive',
#   'incidents',
#   'restrictions',
#   'james',
#   'law',
#   'gain',
#   'coke',
#   'film',
#   'effective',
#   'prose',
#   'post'],
#  ['op',
#   'aspects',
#   'anglo',
#   'dollars',
#   'offensive',
#   'information',
#   'doses',
#   'limitation',
#   'colonial',
#   'salisbury',
#   'age',
#   'anti',
#   'expansion',
#   'incidents',
#   'formations',
#   'plantations',
#   'young',
#   'phrases',
#   'james',
#   'vaccination',
#   'marks',
#   'london',
#   'cycle',
#   'arthur',
#   'effective',
#   'prose',
#   'hostile',
#   'situations',
#   'index',
#   'invitation',
#   'post',
#   'palestine',
#   'club',
#   'film',
#   'cf',
#   'arrangements'],
#  ['op',
#   'cf',
#   'aspects',
#   'colonial',
#   'doses',
#   'limitation',
#   'vaccination',
#   'plantations',
#   'dollars',
#   'index',
#   'cycle',
#   'anti',
#   'concept',
#   'age',
#   'formations',
#   'anglo',
#   'offensive',
#   'london',
#   'expansion',
#   'post',
#   'phrases',
#   'information',
#   'situations',
#   'wilson',
#   'marks',
#   'effective',
#   'incidents',
#   'hostile',
#   'prose',
#   'film',
#   'calcium',
#   'palestine',
#   'immigration',
#   'restrictions',
#   'rate',
#   'james',
#   'gain',
#   'young'],
#  ['op',
#   'aspects',
#   'colonial',
#   'pope',
#   'offensive',
#   'london',
#   'plantations',
#   'film',
#   'formations',
#   'doses',
#   'james',
#   'dollars',
#   'index',
#   'limitation',
#   'concept',
#   'cycle',
#   'anti',
#   'expansion',
#   'age',
#   'information',
#   'effective',
#   'vaccination',
#   'cf',
#   'situations',
#   'arthur',
#   'phrases',
#   'calcium',
#   'anglo',
#   'lots',
#   'stocks',
#   'stable',
#   'club',
#   'incidents',
#   'gain',
#   'prose',
#   'william'],
#  ['op',
#   'cf',
#   'aspects',
#   'colonial',
#   'limitation',
#   'london',
#   'dollars',
#   'information',
#   'formations',
#   'anti',
#   'doses',
#   'expansion',
#   'effective',
#   'plantations',
#   'index',
#   'age',
#   'offensive',
#   'cycle',
#   'palestine',
#   'calcium',
#   'vaccination',
#   'film',
#   'anglo',
#   'situations',
#   'post',
#   'restrictions',
#   'extra',
#   'gain',
#   'arthur',
#   'hostile',
#   'justification',
#   'phrases',
#   'concept',
#   'incidents',
#   'initial',
#   'marks',
#   'stable',
#   'stocks',
#   'wagon'],
#  ['aspects',
#   'cf',
#   'op',
#   'doses',
#   'age',
#   'cycle',
#   'formations',
#   'dollars',
#   'colonial',
#   'london',
#   'expansion',
#   'anti',
#   'offensive',
#   'circuits',
#   'index',
#   'limitation',
#   'anglo',
#   'information',
#   'film',
#   'vaccination',
#   'plantations',
#   'phrases',
#   'james',
#   'post',
#   'situations',
#   'calcium',
#   'restrictions',
#   'effective',
#   'gain',
#   'message',
#   'wilson',
#   'stable',
#   'william',
#   'concept',
#   'rate',
#   'prose',
#   'club',
#   'lectures',
#   'incidents'],
#  ['op',
#   'aspects',
#   'colonial',
#   'formations',
#   'index',
#   'cycle',
#   'dollars',
#   'doses',
#   'offensive',
#   'limitation',
#   'cf',
#   'plantations',
#   'calcium',
#   'information',
#   'concept',
#   'expansion',
#   'age',
#   'london',
#   'anti',
#   'med',
#   'effective',
#   'post',
#   'situations',
#   'phrases',
#   'stable',
#   'anglo',
#   'film',
#   'restrictions',
#   'initial',
#   'roosevelt',
#   'stocks',
#   'dollar',
#   'concepts',
#   'law',
#   'vaccination',
#   'aluminium',
#   'extra',
#   'message',
#   'gain',
#   'daniel'],
#  ['cf',
#   'aspects',
#   'op',
#   'cycle',
#   'colonial',
#   'expansion',
#   'doses',
#   'age',
#   'vaccination',
#   'formations',
#   'information',
#   'index',
#   'london',
#   'shelley',
#   'initial',
#   'dollars',
#   'plantations',
#   'post',
#   'calcium',
#   'stable',
#   'limitation',
#   'phrases',
#   'aluminium',
#   'anti',
#   'situations',
#   'film',
#   'effective',
#   'anglo',
#   'concept',
#   'offensive',
#   'butler',
#   'plants',
#   'gain',
#   'nice',
#   'restrictions'],
#  ['aspects',
#   'op',
#   'colonial',
#   'doses',
#   'formations',
#   'london',
#   'plantations',
#   'age',
#   'anti',
#   'cycle',
#   'expansion',
#   'index',
#   'concept',
#   'information',
#   'calcium',
#   'offensive',
#   'palestine',
#   'limitation',
#   'plants',
#   'dollars',
#   'rate',
#   'anglo',
#   'effective',
#   'cf',
#   'vaccination',
#   'stable',
#   'post',
#   'plantation',
#   'film',
#   'situations',
#   'initial',
#   'phrases',
#   'aluminium',
#   'stocks',
#   'med',
#   'gain',
#   'extra',
#   'message',
#   'prose',
#   'hostile',
#   'restrictions'],
#  ['aspects',
#   'op',
#   'doses',
#   'formations',
#   'colonial',
#   'anti',
#   'cycle',
#   'expansion',
#   'vaccination',
#   'index',
#   'information',
#   'plantations',
#   'age',
#   'london',
#   'dollars',
#   'calcium',
#   'cf',
#   'film',
#   'post',
#   'anglo',
#   'limitation',
#   'initial',
#   'concept',
#   'effective',
#   'phrases',
#   'stable',
#   'offensive',
#   'palestine',
#   'stocks',
#   'plantation',
#   'situations',
#   'incidents',
#   'aluminium',
#   'rate',
#   'plants',
#   'restrictions',
#   'changes',
#   'justification',
#   'extra',
#   'education',
#   'gain',
#   'club',
#   'rural'],
#  ['op',
#   'aspects',
#   'doses',
#   'dollars',
#   'cycle',
#   'london',
#   'age',
#   'information',
#   'expansion',
#   'colonial',
#   'plantations',
#   'formations',
#   'anti',
#   'vaccination',
#   'index',
#   'anglo',
#   'film',
#   'rate',
#   'concept',
#   'post',
#   'limitation',
#   'cf',
#   'effective',
#   'phrases',
#   'plantation',
#   'changes',
#   'chamberlain',
#   'situations',
#   'calcium',
#   'stable',
#   'restrictions',
#   'plants',
#   'initial',
#   'extra',
#   'law',
#   'offensive',
#   'rural',
#   'hostile',
#   'incidents',
#   'palestine',
#   'education',
#   'aluminium',
#   'stocks',
#   'message',
#   'stock',
#   'med',
#   'justification',
#   'report',
#   'gain',
#   'concepts',
#   'william',
#   'test',
#   'infections',
#   'irrigation'],
#  ['op',
#   'aspects',
#   'formations',
#   'doses',
#   'cycle',
#   'dollars',
#   'vaccination',
#   'age',
#   'colonial',
#   'information',
#   'plantations',
#   'expansion',
#   'anti',
#   'prose',
#   'changes',
#   'calcium',
#   'index',
#   'stocks',
#   'anglo',
#   'restrictions',
#   'post',
#   'test',
#   'offensive',
#   'london',
#   'extra',
#   'limitation',
#   'stable',
#   'film',
#   'cf',
#   'aluminium',
#   'effective',
#   'plantation',
#   'passive',
#   'rural',
#   'phrases',
#   'initial',
#   'concept',
#   'rate',
#   'message',
#   'gain',
#   'incidents',
#   'roosevelt',
#   'situations',
#   'stock',
#   'plants',
#   'chamberlain',
#   'accumulation',
#   'justification',
#   'pin'],
#  ['op',
#   'aspects',
#   'formations',
#   'cycle',
#   'doses',
#   'cf',
#   'information',
#   'plantations',
#   'age',
#   'plantation',
#   'london',
#   'anti',
#   'anglo',
#   'expansion',
#   'stocks',
#   'aluminium',
#   'plants',
#   'changes',
#   'colonial',
#   'concept',
#   'dollars',
#   'index',
#   'offensive',
#   'phrases',
#   'film',
#   'vaccination',
#   'restrictions',
#   'stable',
#   'reconstruction',
#   'calcium',
#   'limitation',
#   'situations',
#   'message',
#   'effective',
#   'version',
#   'rate',
#   'initial',
#   'gain',
#   'report',
#   'med',
#   'test',
#   'justification',
#   'support'],
#  ['op',
#   'aspects',
#   'formations',
#   'doses',
#   'anti',
#   'cycle',
#   'stocks',
#   'plantations',
#   'age',
#   'phrases',
#   'offensive',
#   'cf',
#   'expansion',
#   'information',
#   'reconstruction',
#   'concept',
#   'message',
#   'colonial',
#   'calcium',
#   'anglo',
#   'initial',
#   'act',
#   'stable',
#   'dollars',
#   'limitation',
#   'plantation',
#   'aluminium',
#   'education',
#   'restrictions',
#   'clan',
#   'effective',
#   'index',
#   'film',
#   'plants',
#   'post',
#   'london',
#   'lots',
#   'rural',
#   'pin',
#   'time',
#   'prose',
#   'geo',
#   'test',
#   'gain',
#   'situations',
#   'case'],
#  ['op',
#   'aspects',
#   'formations',
#   'cycle',
#   'plantations',
#   'age',
#   'plants',
#   'dollars',
#   'cf',
#   'information',
#   'plantation',
#   'reconstruction',
#   'expansion',
#   'anti',
#   'pin',
#   'colonial',
#   'offensive',
#   'doses',
#   'calcium',
#   'post',
#   'index',
#   'message',
#   'anglo',
#   'rural',
#   'phrases',
#   'limitation',
#   'stocks',
#   'effective',
#   'initial',
#   'restrictions',
#   'stable',
#   'situations',
#   'roosevelt',
#   'film',
#   'concept',
#   'clan',
#   'gain',
#   'london',
#   'editions',
#   'case',
#   'calories'],
#  ['op',
#   'aspects',
#   'cycle',
#   'expansion',
#   'anglo',
#   'information',
#   'anti',
#   'concept',
#   'message',
#   'colonial',
#   'age',
#   'formations',
#   'doses',
#   'offensive',
#   'reconstruction',
#   'aluminium',
#   'cf',
#   'dollars',
#   'stable',
#   'initial',
#   'stocks',
#   'calcium',
#   'concepts',
#   'attitudes',
#   'phrases',
#   'pin',
#   'rural',
#   'gain',
#   'fluctuations',
#   'limitation',
#   'situations',
#   'editions',
#   'index',
#   'film',
#   'effective',
#   'arthur',
#   'post',
#   'plantations',
#   'restrictions',
#   'roosevelt',
#   'justification',
#   'vital',
#   'extra',
#   'stock',
#   'london',
#   'education',
#   'support',
#   'prose',
#   'case',
#   'estimation',
#   'test'],
#  ['op',
#   'aspects',
#   'formations',
#   'reconstruction',
#   'information',
#   'plantations',
#   'expansion',
#   'cycle',
#   'dollars',
#   'present',
#   'colonial',
#   'government',
#   'cf',
#   'anglo',
#   'age',
#   'concept',
#   'london',
#   'united',
#   'plantation',
#   'anti',
#   'message',
#   'stocks',
#   'offensive',
#   'time',
#   'situations',
#   'limitation',
#   'pin',
#   'phrases',
#   'restrictions',
#   'effective',
#   'states',
#   'plants',
#   'gain',
#   'stable',
#   'editions',
#   'president',
#   'aluminium',
#   'film',
#   'stock',
#   'fluctuations',
#   'treaty',
#   'rural',
#   'index',
#   'case',
#   'justification',
#   'initial',
#   'glacier',
#   'vital',
#   'roosevelt',
#   'concepts',
#   'high',
#   'james'],
#  ['aspects',
#   'reconstruction',
#   'mass',
#   'op',
#   'anglo',
#   'message',
#   'information',
#   'roosevelt',
#   'offensive',
#   'expansion',
#   'anti',
#   'film',
#   'dollars',
#   'formations',
#   'palestine',
#   'cf',
#   'colonial',
#   'cycle',
#   'concept',
#   'age',
#   'effective',
#   'william',
#   'phrases',
#   'stocks',
#   'arthur',
#   'alaska',
#   'hostile',
#   'wilson',
#   'stable',
#   'aluminium',
#   'limitation',
#   'nazis',
#   'situations',
#   'editions',
#   'contacts',
#   'changes',
#   'justification',
#   'doses',
#   'gain',
#   'initial',
#   'vital',
#   'london',
#   'restrictions',
#   'club',
#   'incidents',
#   'prose',
#   'plantations',
#   'concepts',
#   'manchester',
#   'block',
#   'index',
#   'james',
#   'post'],
#  ['aspects',
#   'op',
#   'information',
#   'reconstruction',
#   'film',
#   'cycle',
#   'expansion',
#   'concept',
#   'formations',
#   'anglo',
#   'dollars',
#   'age',
#   'colonial',
#   'anti',
#   'message',
#   'phrases',
#   'effective',
#   'palestine',
#   'situations',
#   'concepts',
#   'cf',
#   'stocks',
#   'plantations',
#   'offensive',
#   'stable',
#   'limitation',
#   'rural',
#   'justification',
#   'editions',
#   'contacts',
#   'post',
#   'intelligible',
#   'aluminium',
#   'plants',
#   'prose',
#   'gain',
#   'hostile',
#   'sand',
#   'index',
#   'incidents',
#   'initial',
#   'doses',
#   'london',
#   'oppose',
#   'contemplation',
#   'attitudes',
#   'restrictions',
#   'plantation',
#   'vital',
#   'structures',
#   'changes',
#   'accumulation',
#   'stock',
#   'club',
#   'james',
#   'musical',
#   'time',
#   'vaccination',
#   'william',
#   'immigration',
#   'education'],
#  ['op',
#   'aspects',
#   'reconstruction',
#   'expansion',
#   'information',
#   'film',
#   'anglo',
#   'cycle',
#   'dollars',
#   'offensive',
#   'anti',
#   'concept',
#   'formations',
#   'colonial',
#   'plantations',
#   'plants',
#   'age',
#   'message',
#   'effective',
#   'situations',
#   'phrases',
#   'cf',
#   'stable',
#   'concepts',
#   'ferry',
#   'editions',
#   'marks',
#   'limitation',
#   'rural',
#   'stocks',
#   'justification',
#   'initial',
#   'pin',
#   'structures',
#   'plantation',
#   'doses',
#   'gain',
#   'vital',
#   'london',
#   'aluminium',
#   'contacts',
#   'hostile',
#   'incidents',
#   'oppose',
#   'palestine',
#   'index',
#   'james',
#   'support',
#   'attitudes',
#   'test',
#   'roosevelt',
#   'accumulation',
#   'post',
#   'changes',
#   'dense',
#   'prose',
#   'intelligible'],
#  ['aspects',
#   'dollars',
#   'op',
#   'reconstruction',
#   'information',
#   'film',
#   'cycle',
#   'expansion',
#   'marshall',
#   'formations',
#   'anglo',
#   'concept',
#   'anti',
#   'palestine',
#   'plantations',
#   'london',
#   'offensive',
#   'message',
#   'test',
#   'situations',
#   'age',
#   'colonial',
#   'effective',
#   'cf',
#   'stable',
#   'tests',
#   'structures',
#   'aluminium',
#   'doses',
#   'plants',
#   'phrases',
#   'index',
#   'initial',
#   'contacts',
#   'james',
#   'restrictions',
#   'editions',
#   'justification',
#   'stocks',
#   'gain',
#   'calcium',
#   'roosevelt',
#   'concepts',
#   'rural',
#   'hostile',
#   'changes',
#   'post',
#   'limitation',
#   'oppose',
#   'vital',
#   'time',
#   'attitudes',
#   'prose',
#   'immigration',
#   'daniel',
#   'support',
#   'plantation',
#   'accumulation',
#   'fluctuations',
#   'william',
#   'pin',
#   'incidents',
#   'club',
#   'dense',
#   'standard'],
#  ['aspects',
#   'op',
#   'information',
#   'dollars',
#   'cycle',
#   'film',
#   'expansion',
#   'formations',
#   'structures',
#   'reconstruction',
#   'concept',
#   'anti',
#   'message',
#   'age',
#   'cf',
#   'situations',
#   'plantations',
#   'colonial',
#   'anglo',
#   'london',
#   'time',
#   'test',
#   'effective',
#   'contacts',
#   'musical',
#   'rural',
#   'marshall',
#   'immigration',
#   'stable',
#   'phrases',
#   'doses',
#   'limitation',
#   'initial',
#   'plants',
#   'post',
#   'concepts',
#   'offensive',
#   'tests',
#   'index',
#   'irrigation',
#   'plantation',
#   'soil',
#   'attitudes',
#   'support',
#   'justification',
#   'gain',
#   'changes',
#   'palestine',
#   'editions',
#   'club',
#   'dense',
#   'restrictions',
#   'daniel',
#   'stocks',
#   'hostile',
#   'site',
#   'fluctuations',
#   'accumulation',
#   'use',
#   'calcium',
#   'oppose',
#   'case',
#   'report',
#   'university',
#   'education',
#   'aluminium',
#   'james',
#   'extra'],
#  ['aspects',
#   'op',
#   'information',
#   'dollars',
#   'cycle',
#   'formations',
#   'film',
#   'reconstruction',
#   'expansion',
#   'test',
#   'concept',
#   'age',
#   'anti',
#   'structures',
#   'cf',
#   'situations',
#   'london',
#   'colonial',
#   'plantations',
#   'doses',
#   'anglo',
#   'concepts',
#   'effective',
#   'time',
#   'law',
#   'message',
#   'plants',
#   'index',
#   'tests',
#   'post',
#   'limitation',
#   'stable',
#   'immigration',
#   'rural',
#   'initial',
#   'contacts',
#   'offensive',
#   'aluminium',
#   'daniel',
#   'phrases',
#   'marshall',
#   'justification',
#   'identification',
#   'editions',
#   'changes',
#   'standard',
#   'university',
#   'irrigation',
#   'attitudes',
#   'accumulation',
#   'extra',
#   'plantation',
#   'gain',
#   'education',
#   'motion',
#   'support',
#   'oppose',
#   'case',
#   'fluctuations',
#   'calcium',
#   'james',
#   'stocks',
#   'restrictions',
#   'dense',
#   'arthur',
#   'hostile',
#   'vital',
#   'report',
#   'pin'],
#  ['aspects',
#   'information',
#   'op',
#   'dollars',
#   'expansion',
#   'cycle',
#   'film',
#   'concept',
#   'age',
#   'formations',
#   'structures',
#   'london',
#   'anti',
#   'anglo',
#   'law',
#   'plantations',
#   'test',
#   'situations',
#   'reconstruction',
#   'plants',
#   'index',
#   'cf',
#   'concepts',
#   'doses',
#   'tests',
#   'effective',
#   'message',
#   'time',
#   'stable',
#   'limitation',
#   'colonial',
#   'initial',
#   'contacts',
#   'arthur',
#   'case',
#   'support',
#   'editions',
#   'attitudes',
#   'post',
#   'immigration',
#   'gain',
#   'plantation',
#   'phrases',
#   'offensive',
#   'irrigation',
#   'club',
#   'justification',
#   'fluctuations',
#   'rural',
#   'education',
#   'standard',
#   'report',
#   'accumulation',
#   'university',
#   'changes',
#   'cases',
#   'identification',
#   'courts',
#   'extra',
#   'restrictions',
#   'dense',
#   'vaccination',
#   'marshall',
#   'calcium',
#   'hostile',
#   'incidents',
#   'stage',
#   'aluminium',
#   'american',
#   'james',
#   'use'],
#  ['aspects',
#   'op',
#   'information',
#   'dollars',
#   'cycle',
#   'expansion',
#   'anti',
#   'film',
#   'formations',
#   'structures',
#   'test',
#   'index',
#   'concept',
#   'plantations',
#   'reconstruction',
#   'age',
#   'cf',
#   'situations',
#   'plants',
#   'london',
#   'law',
#   'post',
#   'stable',
#   'effective',
#   'anglo',
#   'rural',
#   'initial',
#   'plantation',
#   'tests',
#   'limitation',
#   'message',
#   'irrigation',
#   'stocks',
#   'doses',
#   'time',
#   'colonial',
#   'justification',
#   'contacts',
#   'changes',
#   'case',
#   'gain',
#   'aluminium',
#   'accumulation',
#   'concepts',
#   'extra',
#   'attitudes',
#   'fluctuations',
#   'standard',
#   'james',
#   'report',
#   'editions',
#   'restrictions',
#   'stock',
#   'estimation',
#   'calcium',
#   'support',
#   'identification',
#   'vaccination',
#   'university',
#   'stage',
#   'courts',
#   'phrases',
#   'offensive',
#   'lots',
#   'dominant',
#   'dense',
#   'corrosion',
#   'education',
#   'pin',
#   'evolution',
#   'oppose'],
#  ['aspects',
#   'op',
#   'information',
#   'dollars',
#   'expansion',
#   'cycle',
#   'structures',
#   'concept',
#   'situations',
#   'anti',
#   'formations',
#   'film',
#   'london',
#   'cf',
#   'reconstruction',
#   'colonial',
#   'plantations',
#   'anglo',
#   'age',
#   'club',
#   'message',
#   'effective',
#   'attitudes',
#   'contacts',
#   'index',
#   'case',
#   'test',
#   'law',
#   'stable',
#   'irrigation',
#   'rural',
#   'immigration',
#   'post',
#   'limitation',
#   'concepts',
#   'initial',
#   'time',
#   'gain',
#   'fluctuations',
#   'justification',
#   'doses',
#   'tests',
#   'stocks',
#   'restrictions',
#   'offensive',
#   'james',
#   'plants',
#   'editions',
#   'identification',
#   'phrases',
#   'education',
#   'extra',
#   'plantation',
#   'university',
#   'estimation',
#   'aluminium',
#   'accumulation',
#   'calcium',
#   'report',
#   'support',
#   'location',
#   'standard',
#   'hostile',
#   'oppose',
#   'american',
#   'changes',
#   'dense',
#   'cases'],
#  ['aspects',
#   'op',
#   'information',
#   'expansion',
#   'cycle',
#   'test',
#   'dollars',
#   'film',
#   'structures',
#   'formations',
#   'concept',
#   'anti',
#   'cf',
#   'london',
#   'situations',
#   'plantations',
#   'tests',
#   'age',
#   'index',
#   'plants',
#   'anglo',
#   'reconstruction',
#   'contacts',
#   'time',
#   'effective',
#   'rural',
#   'message',
#   'attitudes',
#   'colonial',
#   'post',
#   'fluctuations',
#   'stable',
#   'limitation',
#   'concepts',
#   'law',
#   'doses',
#   'initial',
#   'aluminium',
#   'irrigation',
#   'stocks',
#   'case',
#   'gain',
#   'report',
#   'education',
#   'support',
#   'plantation',
#   'editions',
#   'justification',
#   'standard',
#   'phrases',
#   'textile',
#   'immigration',
#   'extra',
#   'use',
#   'university',
#   'james',
#   'lots',
#   'version',
#   'identification',
#   'vaccination',
#   'accumulation',
#   'estimation',
#   'stock',
#   'oppose',
#   'american',
#   'courts',
#   'restrictions',
#   'dense',
#   'william',
#   'stage',
#   'hostile',
#   'changes',
#   'daniel',
#   'vital',
#   'incidents'],
#  ['aspects',
#   'information',
#   'op',
#   'expansion',
#   'structures',
#   'cycle',
#   'concept',
#   'anti',
#   'film',
#   'london',
#   'dollars',
#   'age',
#   'test',
#   'cf',
#   'formations',
#   'situations',
#   'plantations',
#   'contacts',
#   'wilson',
#   'anglo',
#   'law',
#   'concepts',
#   'message',
#   'aluminium',
#   'index',
#   'time',
#   'case',
#   'limitation',
#   'tests',
#   'plantation',
#   'post',
#   'lloyd',
#   'reconstruction',
#   'rural',
#   'doses',
#   'plants',
#   'stable',
#   'calcium',
#   'effective',
#   'colonial',
#   'attitudes',
#   'initial',
#   'editions',
#   'education',
#   'irrigation',
#   'gain',
#   'justification',
#   'cases',
#   'identification',
#   'university',
#   'fluctuations',
#   'intelligible',
#   'support',
#   'patient',
#   'accumulation',
#   'william',
#   'report',
#   'version',
#   'stocks',
#   'james',
#   'lots',
#   'circuits',
#   'vaccination',
#   'standard',
#   'dense',
#   'phrases',
#   'american',
#   'extra',
#   'evolution',
#   'oppose',
#   'courts',
#   'use',
#   'changes',
#   'med',
#   'restrictions',
#   'hostile',
#   'promotion',
#   'incidents',
#   'ml',
#   'united',
#   'daniel'],
#  ['aspects',
#   'expansion',
#   'information',
#   'op',
#   'structures',
#   'film',
#   'cycle',
#   'dollars',
#   'formations',
#   'anti',
#   'age',
#   'situations',
#   'concept',
#   'test',
#   'cf',
#   'rural',
#   'contacts',
#   'message',
#   'london',
#   'plantations',
#   'index',
#   'stable',
#   'post',
#   'reconstruction',
#   'doses',
#   'effective',
#   'tests',
#   'gain',
#   'limitation',
#   'attitudes',
#   'anglo',
#   'initial',
#   'editions',
#   'justification',
#   'accumulation',
#   'fluctuations',
#   'irrigation',
#   'time',
#   'concepts',
#   'colonial',
#   'plantation',
#   'plants',
#   'law',
#   'phrases',
#   'estimation',
#   'textile',
#   'standard',
#   'aluminium',
#   'university',
#   'support',
#   'education',
#   'calcium',
#   'stocks',
#   'immigration',
#   'extra',
#   'promotion',
#   'version',
#   'identification',
#   'case',
#   'cases',
#   'report',
#   'dense',
#   'evolution',
#   'oppose',
#   'patient',
#   'incidents',
#   'cycles',
#   'lots',
#   'uranium',
#   'radiation',
#   'daniel',
#   'hostile',
#   'stock',
#   'restrictions',
#   'stage'],
#  ['aspects',
#   'op',
#   'information',
#   'expansion',
#   'structures',
#   'dollars',
#   'cycle',
#   'uranium',
#   'film',
#   'anti',
#   'cf',
#   'concept',
#   'situations',
#   'formations',
#   'london',
#   'message',
#   'age',
#   'corrosion',
#   'contacts',
#   'plantations',
#   'test',
#   'rural',
#   'effective',
#   'index',
#   'aluminium',
#   'post',
#   'tests',
#   'anglo',
#   'stable',
#   'editions',
#   'limitation',
#   'doses',
#   'reconstruction',
#   'concepts',
#   'time',
#   'law',
#   'irrigation',
#   'education',
#   'stocks',
#   'restrictions',
#   'initial',
#   'attitudes',
#   'accumulation',
#   'justification',
#   'plantation',
#   'version',
#   'identification',
#   'plants',
#   'university',
#   'james',
#   'changes',
#   'colonial',
#   'discrimination',
#   'evolution',
#   'standard',
#   'gain',
#   'fluctuations',
#   'extra',
#   'report',
#   'offensive',
#   'phrases',
#   'stage',
#   'incidents',
#   'case',
#   'rites',
#   'chicago',
#   'promotion',
#   'calcium',
#   'hostile',
#   'cases',
#   'ml',
#   'oppose',
#   'estimation',
#   'support',
#   'william'],
#  ['aspects',
#   'information',
#   'expansion',
#   'op',
#   'structures',
#   'cycle',
#   'dollars',
#   'formations',
#   'film',
#   'cf',
#   'anti',
#   'concept',
#   'situations',
#   'message',
#   'age',
#   'test',
#   'contacts',
#   'rural',
#   'limitation',
#   'index',
#   'london',
#   'law',
#   'gain',
#   'post',
#   'effective',
#   'stable',
#   'aluminium',
#   'plantations',
#   'doses',
#   'attitudes',
#   'initial',
#   'ml',
#   'concepts',
#   'anglo',
#   'irrigation',
#   'uranium',
#   'calcium',
#   'colonial',
#   'time',
#   'accumulation',
#   'reconstruction',
#   'tests',
#   'stocks',
#   'promotion',
#   'justification',
#   'restrictions',
#   'plants',
#   'case',
#   'editions',
#   'education',
#   'extra',
#   'fluctuations',
#   'identification',
#   'phrases',
#   'circuits',
#   'standard',
#   'support',
#   'cycles',
#   'immigration',
#   'incidents',
#   'report',
#   'discrimination',
#   'estimation',
#   'version',
#   'plantation',
#   'university',
#   'stock',
#   'evolution',
#   'dense',
#   'offensive',
#   'oppose',
#   'cases',
#   'stage',
#   'hostile',
#   'club',
#   'patient'],
#  ['expansion',
#   'aspects',
#   'structures',
#   'information',
#   'op',
#   'cycle',
#   'dollars',
#   'formations',
#   'cf',
#   'anti',
#   'situations',
#   'concept',
#   'film',
#   'age',
#   'test',
#   'rural',
#   'london',
#   'contacts',
#   'message',
#   'limitation',
#   'uranium',
#   'attitudes',
#   'index',
#   'concepts',
#   'effective',
#   'fluctuations',
#   'stable',
#   'post',
#   'aluminium',
#   'gain',
#   'anglo',
#   'colonial',
#   'accumulation',
#   'initial',
#   'promotion',
#   'doses',
#   'stocks',
#   'tests',
#   'editions',
#   'phrases',
#   'reconstruction',
#   'justification',
#   'restrictions',
#   'plantations',
#   'time',
#   'ml',
#   'circuits',
#   'extra',
#   'evolution',
#   'university',
#   'identification',
#   'law',
#   'estimation',
#   'discrimination',
#   'ms',
#   'changes',
#   'education',
#   'support',
#   'calcium',
#   'version',
#   'irrigation',
#   'case',
#   'report',
#   'site',
#   'plants',
#   'james',
#   'hostile',
#   'incidents',
#   'standard',
#   'stock',
#   'cycles',
#   'oppose',
#   'patient',
#   'daniel',
#   'textile',
#   'cases',
#   'dominant',
#   'club',
#   'plantation',
#   'motion',
#   'rites'],
#  ['aspects',
#   'information',
#   'structures',
#   'op',
#   'expansion',
#   'cycle',
#   'film',
#   'dollars',
#   'anti',
#   'test',
#   'rural',
#   'situations',
#   'age',
#   'cf',
#   'concept',
#   'formations',
#   'contacts',
#   'index',
#   'london',
#   'message',
#   'attitudes',
#   'promotion',
#   'tests',
#   'editions',
#   'effective',
#   'limitation',
#   'post',
#   'stable',
#   'uranium',
#   'accumulation',
#   'doses',
#   'gain',
#   'time',
#   'concepts',
#   'identification',
#   'stocks',
#   'ml',
#   'initial',
#   'extra',
#   'case',
#   'aluminium',
#   'evolution',
#   'law',
#   'plantations',
#   'justification',
#   'anglo',
#   'textile',
#   'phrases',
#   'restrictions',
#   'report',
#   'calcium',
#   'education',
#   'fluctuations',
#   'reconstruction',
#   'estimation',
#   'colonial',
#   'university',
#   'version',
#   'irrigation',
#   'incidents',
#   'discrimination',
#   'motion',
#   'support',
#   'patient',
#   'nice',
#   'plantation',
#   'cases',
#   'standard',
#   'mental',
#   'plants',
#   'daniel',
#   'circuits',
#   'changes',
#   'hostile',
#   'offensive',
#   'oppose',
#   'dense',
#   'club'],
#  ['aspects',
#   'information',
#   'structures',
#   'expansion',
#   'op',
#   'cycle',
#   'dollars',
#   'film',
#   'concept',
#   'situations',
#   'rural',
#   'age',
#   'anti',
#   'promotion',
#   'message',
#   'formations',
#   'cf',
#   'aluminium',
#   'contacts',
#   'london',
#   'attitudes',
#   'test',
#   'index',
#   'concepts',
#   'stable',
#   'ml',
#   'editions',
#   'irrigation',
#   'limitation',
#   'accumulation',
#   'post',
#   'education',
#   'effective',
#   'tests',
#   'gain',
#   'colonial',
#   'identification',
#   'initial',
#   'support',
#   'plantations',
#   'doses',
#   'fluctuations',
#   'justification',
#   'version',
#   'stocks',
#   'estimation',
#   'anglo',
#   'phrases',
#   'university',
#   'time',
#   'patient',
#   'restrictions',
#   'reconstruction',
#   'circuits',
#   'extra',
#   'stage',
#   'textile',
#   'oppose',
#   'standard',
#   'uranium',
#   'james',
#   'incidents',
#   'evolution',
#   'calcium',
#   'site',
#   'dense',
#   'discrimination',
#   'report',
#   'hostile',
#   'rites',
#   'cycles',
#   'plantation'],
#  ['information',
#   'aspects',
#   'structures',
#   'expansion',
#   'op',
#   'cycle',
#   'dollars',
#   'film',
#   'anti',
#   'concept',
#   'situations',
#   'cf',
#   'age',
#   'contacts',
#   'rural',
#   'attitudes',
#   'test',
#   'london',
#   'promotion',
#   'message',
#   'formations',
#   'education',
#   'index',
#   'effective',
#   'ml',
#   'concepts',
#   'tests',
#   'limitation',
#   'initial',
#   'stable',
#   'post',
#   'editions',
#   'anglo',
#   'aluminium',
#   'time',
#   'identification',
#   'uranium',
#   'phrases',
#   'fluctuations',
#   'gain',
#   'colonial',
#   'estimation',
#   'stocks',
#   'offensive',
#   'accumulation',
#   'justification',
#   'restrictions',
#   'evolution',
#   'plantations',
#   'version',
#   'support',
#   'university',
#   'stage',
#   'reconstruction',
#   'incidents',
#   'doses',
#   'extra',
#   'irrigation',
#   'club',
#   'law',
#   'case',
#   'hostile',
#   'report',
#   'oppose',
#   'motion',
#   'textile',
#   'doc',
#   'circuits',
#   'standard',
#   'cycles',
#   'discrimination',
#   'philippines'],
#  ['information',
#   'aspects',
#   'structures',
#   'expansion',
#   'op',
#   'cycle',
#   'dollars',
#   'situations',
#   'concept',
#   'rural',
#   'anti',
#   'film',
#   'age',
#   'cf',
#   'promotion',
#   'attitudes',
#   'london',
#   'message',
#   'contacts',
#   'index',
#   'test',
#   'education',
#   'formations',
#   'concepts',
#   'effective',
#   'version',
#   'ml',
#   'stable',
#   'post',
#   'initial',
#   'editions',
#   'identification',
#   'limitation',
#   'estimation',
#   'accumulation',
#   'gain',
#   'university',
#   'phrases',
#   'tests',
#   'law',
#   'plantations',
#   'justification',
#   'time',
#   'extra',
#   'irrigation',
#   'evolution',
#   'circuits',
#   'anglo',
#   'aluminium',
#   'case',
#   'restrictions',
#   'textile',
#   'fluctuations',
#   'patient',
#   'stage',
#   'colonial',
#   'doses',
#   'stocks',
#   'reconstruction',
#   'support',
#   'james',
#   'report',
#   'immigration',
#   'uranium',
#   'oppose',
#   'plantation',
#   'site',
#   'william',
#   'cycles',
#   'discrimination',
#   'standard',
#   'hostile',
#   'incidents',
#   'offensive',
#   'stimulus',
#   'notices',
#   'changes',
#   'daniel'],
#  ['information',
#   'aspects',
#   'structures',
#   'expansion',
#   'op',
#   'cycle',
#   'dollars',
#   'concept',
#   'rural',
#   'london',
#   'situations',
#   'anti',
#   'age',
#   'cf',
#   'index',
#   'film',
#   'promotion',
#   'contacts',
#   'attitudes',
#   'formations',
#   'message',
#   'education',
#   'test',
#   'editions',
#   'concepts',
#   'ml',
#   'stable',
#   'limitation',
#   'aluminium',
#   'effective',
#   'post',
#   'gain',
#   'evolution',
#   'anglo',
#   'circuits',
#   'initial',
#   'version',
#   'university',
#   'time',
#   'identification',
#   'phrases',
#   'justification',
#   'tests',
#   'offensive',
#   'accumulation',
#   'support',
#   'extra',
#   'restrictions',
#   'reconstruction',
#   'estimation',
#   'irrigation',
#   'club',
#   'uranium',
#   'stocks',
#   'fluctuations',
#   'colonial',
#   'patient',
#   'doses',
#   'hostile',
#   'immigration',
#   'discrimination',
#   'stage',
#   'textile',
#   'plantations',
#   'oppose',
#   'daniel',
#   'law',
#   'james',
#   'incidents',
#   'motion',
#   'standard',
#   'nice',
#   'site',
#   'case',
#   'report'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'expansion',
#   'cycle',
#   'concept',
#   'dollars',
#   'rural',
#   'situations',
#   'anti',
#   'age',
#   'film',
#   'london',
#   'cf',
#   'index',
#   'promotion',
#   'attitudes',
#   'contacts',
#   'formations',
#   'ml',
#   'message',
#   'test',
#   'concepts',
#   'editions',
#   'education',
#   'effective',
#   'limitation',
#   'initial',
#   'post',
#   'tests',
#   'phrases',
#   'justification',
#   'stable',
#   'version',
#   'accumulation',
#   'uranium',
#   'estimation',
#   'university',
#   'identification',
#   'evolution',
#   'time',
#   'support',
#   'gain',
#   'james',
#   'stocks',
#   'aluminium',
#   'site',
#   'law',
#   'restrictions',
#   'circuits',
#   'reconstruction',
#   'anglo',
#   'irrigation',
#   'club',
#   'daniel',
#   'plantations',
#   'textile',
#   'oppose',
#   'offensive',
#   'fluctuations',
#   'report',
#   'colonial',
#   'stock',
#   'extra',
#   'case',
#   'hostile',
#   'william',
#   'doses',
#   'stage',
#   'standard'],
#  ['information',
#   'structures',
#   'aspects',
#   'expansion',
#   'op',
#   'cycle',
#   'dollars',
#   'concept',
#   'anti',
#   'film',
#   'situations',
#   'rural',
#   'age',
#   'cf',
#   'promotion',
#   'ml',
#   'attitudes',
#   'london',
#   'formations',
#   'message',
#   'contacts',
#   'concepts',
#   'index',
#   'test',
#   'education',
#   'editions',
#   'accumulation',
#   'phrases',
#   'university',
#   'effective',
#   'identification',
#   'limitation',
#   'post',
#   'stable',
#   'initial',
#   'irrigation',
#   'plantations',
#   'estimation',
#   'evolution',
#   'version',
#   'offensive',
#   'anglo',
#   'justification',
#   'gain',
#   'circuits',
#   'tests',
#   'support',
#   'doses',
#   'stocks',
#   'aluminium',
#   'daniel',
#   'club',
#   'time',
#   'restrictions',
#   'colonial',
#   'reconstruction',
#   'gilbert',
#   'textile',
#   'extra',
#   'fluctuations',
#   'oppose',
#   'report',
#   'site',
#   'wilson',
#   'nice',
#   'johnson',
#   'discrimination',
#   'hostile',
#   'benjamin',
#   'incidents',
#   'calcium',
#   'dominant',
#   'immigration',
#   'james',
#   'research',
#   'dense',
#   'stage',
#   'rites'],
#  ['structures',
#   'information',
#   'aspects',
#   'op',
#   'expansion',
#   'cycle',
#   'concept',
#   'dollars',
#   'film',
#   'anti',
#   'situations',
#   'rural',
#   'message',
#   'cf',
#   'age',
#   'attitudes',
#   'promotion',
#   'ml',
#   'formations',
#   'concepts',
#   'contacts',
#   'index',
#   'london',
#   'editions',
#   'test',
#   'post',
#   'identification',
#   'phrases',
#   'education',
#   'version',
#   'effective',
#   'initial',
#   'accumulation',
#   'offensive',
#   'stable',
#   'circuits',
#   'limitation',
#   'university',
#   'palestine',
#   'justification',
#   'support',
#   'anglo',
#   'evolution',
#   'estimation',
#   'tests',
#   'stocks',
#   'gain',
#   'time',
#   'irrigation',
#   'doses',
#   'extra',
#   'colonial',
#   'fluctuations',
#   'club',
#   'oppose',
#   'james',
#   'plantations',
#   'restrictions',
#   'site',
#   'textile',
#   'incidents',
#   'reconstruction',
#   'hostile',
#   'patient',
#   'stage',
#   'mental',
#   'report',
#   'fractions',
#   'daniel',
#   'stock',
#   'law',
#   'aluminium',
#   'massive',
#   'dense',
#   'wilson'],
#  ['structures',
#   'information',
#   'aspects',
#   'op',
#   'expansion',
#   'concept',
#   'cycle',
#   'dollars',
#   'situations',
#   'rural',
#   'anti',
#   'cf',
#   'age',
#   'film',
#   'promotion',
#   'message',
#   'attitudes',
#   'concepts',
#   'london',
#   'index',
#   'contacts',
#   'ml',
#   'editions',
#   'education',
#   'formations',
#   'phrases',
#   'offensive',
#   'test',
#   'identification',
#   'post',
#   'version',
#   'limitation',
#   'effective',
#   'stable',
#   'initial',
#   'support',
#   'accumulation',
#   'evolution',
#   'justification',
#   'university',
#   'circuits',
#   'estimation',
#   'daniel',
#   'club',
#   'time',
#   'gain',
#   'tests',
#   'anglo',
#   'johnson',
#   'stocks',
#   'irrigation',
#   'palestine',
#   'extra',
#   'sport',
#   'doses',
#   'prose',
#   'oppose',
#   'site',
#   'incidents',
#   'patient',
#   'wilson',
#   'restrictions',
#   'stock',
#   'aluminium',
#   'textile',
#   'plantations',
#   'fluctuations',
#   'james',
#   'stage',
#   'sports',
#   'hostile'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'expansion',
#   'dollars',
#   'cycle',
#   'concept',
#   'anti',
#   'situations',
#   'cf',
#   'film',
#   'rural',
#   'age',
#   'message',
#   'promotion',
#   'index',
#   'london',
#   'editions',
#   'contacts',
#   'concepts',
#   'attitudes',
#   'test',
#   'education',
#   'phrases',
#   'ml',
#   'formations',
#   'identification',
#   'evolution',
#   'post',
#   'effective',
#   'limitation',
#   'university',
#   'version',
#   'initial',
#   'time',
#   'support',
#   'justification',
#   'accumulation',
#   'stable',
#   'stocks',
#   'tests',
#   'anglo',
#   'offensive',
#   'estimation',
#   'restrictions',
#   'circuits',
#   'daniel',
#   'stock',
#   'patient',
#   'site',
#   'extra',
#   'stage',
#   'law',
#   'plantations',
#   'gain',
#   'club',
#   'palestine',
#   'james',
#   'rites',
#   'oppose',
#   'textile',
#   'nigeria',
#   'reconstruction',
#   'hostile',
#   'nice',
#   'fluctuations',
#   'immigration',
#   'discrimination',
#   'aluminium',
#   'incidents',
#   'sites',
#   'william',
#   'standard',
#   'case',
#   'dense',
#   'report',
#   'colonial'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'expansion',
#   'cycle',
#   'dollars',
#   'concept',
#   'film',
#   'anti',
#   'cf',
#   'situations',
#   'rural',
#   'message',
#   'age',
#   'promotion',
#   'concepts',
#   'index',
#   'attitudes',
#   'formations',
#   'editions',
#   'london',
#   'education',
#   'contacts',
#   'phrases',
#   'test',
#   'accumulation',
#   'identification',
#   'version',
#   'effective',
#   'limitation',
#   'ml',
#   'post',
#   'stable',
#   'initial',
#   'university',
#   'support',
#   'evolution',
#   'estimation',
#   'justification',
#   'circuits',
#   'site',
#   'gain',
#   'anglo',
#   'restrictions',
#   'daniel',
#   'patient',
#   'offensive',
#   'plantations',
#   'colonial',
#   'palestine',
#   'changes',
#   'tests',
#   'time',
#   'value',
#   'fluctuations',
#   'textile',
#   'stocks',
#   'sites',
#   'oppose',
#   'club',
#   'aluminium',
#   'reconstruction',
#   'case',
#   'incidents',
#   'immigration',
#   'extra',
#   'hostile',
#   'stock',
#   'law',
#   'dominant',
#   'report',
#   'fractions',
#   'cycles',
#   'cardan',
#   'dense'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'expansion',
#   'dollars',
#   'cycle',
#   'concept',
#   'film',
#   'anti',
#   'situations',
#   'rural',
#   'promotion',
#   'cf',
#   'message',
#   'age',
#   'index',
#   'formations',
#   'editions',
#   'education',
#   'concepts',
#   'attitudes',
#   'london',
#   'contacts',
#   'version',
#   'phrases',
#   'test',
#   'identification',
#   'ml',
#   'university',
#   'accumulation',
#   'post',
#   'effective',
#   'evolution',
#   'support',
#   'estimation',
#   'initial',
#   'time',
#   'dollar',
#   'limitation',
#   'stable',
#   'site',
#   'gain',
#   'club',
#   'tests',
#   'circuits',
#   'patient',
#   'immigration',
#   'justification',
#   'daniel',
#   'colonial',
#   'offensive',
#   'stocks',
#   'anglo',
#   'textile',
#   'fluctuations',
#   'sites',
#   'case',
#   'plantations',
#   'changes',
#   'report',
#   'stage',
#   'restrictions',
#   'illustration',
#   'oppose',
#   'extra',
#   'impact',
#   'william',
#   'reconstruction',
#   'continental',
#   'interaction',
#   'dominant',
#   'aluminium',
#   'stock',
#   'fiction',
#   'christian',
#   'research',
#   'hostile',
#   'james',
#   'formulation',
#   'incidents',
#   'nice',
#   'migration',
#   'standard'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'expansion',
#   'cycle',
#   'concept',
#   'film',
#   'dollars',
#   'anti',
#   'cf',
#   'situations',
#   'rural',
#   'promotion',
#   'message',
#   'age',
#   'index',
#   'editions',
#   'formations',
#   'concepts',
#   'london',
#   'phrases',
#   'education',
#   'attitudes',
#   'contacts',
#   'version',
#   'identification',
#   'ml',
#   'accumulation',
#   'test',
#   'limitation',
#   'support',
#   'university',
#   'post',
#   'effective',
#   'stable',
#   'initial',
#   'site',
#   'estimation',
#   'evolution',
#   'time',
#   'dollar',
#   'nixon',
#   'justification',
#   'daniel',
#   'anglo',
#   'sites',
#   'circuits',
#   'gain',
#   'immigration',
#   'club',
#   'tests',
#   'case',
#   'colonial',
#   'impact',
#   'stage',
#   'offensive',
#   'migration',
#   'extra',
#   'rites',
#   'patient',
#   'oppose',
#   'sport',
#   'palestine',
#   'william',
#   'illustration',
#   'report',
#   'plantations',
#   'changes',
#   'restrictions',
#   'reconstruction',
#   'fluctuations',
#   'stock',
#   'stocks',
#   'christian',
#   'discrimination',
#   'nice',
#   'dominant',
#   'james',
#   'hostile',
#   'fiction',
#   'wilson',
#   'interaction',
#   'pakistan',
#   'cycles',
#   'occurrence',
#   'incidents',
#   'dense'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'concept',
#   'expansion',
#   'cycle',
#   'dollars',
#   'rural',
#   'anti',
#   'film',
#   'cf',
#   'situations',
#   'index',
#   'age',
#   'promotion',
#   'message',
#   'concepts',
#   'editions',
#   'phrases',
#   'attitudes',
#   'education',
#   'london',
#   'formations',
#   'contacts',
#   'version',
#   'site',
#   'identification',
#   'ml',
#   'test',
#   'accumulation',
#   'nice',
#   'post',
#   'support',
#   'university',
#   'limitation',
#   'time',
#   'effective',
#   'evolution',
#   'estimation',
#   'stable',
#   'initial',
#   'dollar',
#   'club',
#   'justification',
#   'sites',
#   'daniel',
#   'tests',
#   'impact',
#   'colonial',
#   'gain',
#   'circuits',
#   'fiction',
#   'offensive',
#   'anglo',
#   'oppose',
#   'dominant',
#   'extra',
#   'stocks',
#   'stage',
#   'plantations',
#   'nixon',
#   'illustration',
#   'immigration',
#   'christian',
#   'formulation',
#   'fluctuations',
#   'reconstruction',
#   'james',
#   'stock',
#   'changes',
#   'report',
#   'patient',
#   'aluminium',
#   'restrictions',
#   'william',
#   'interaction',
#   'cycles',
#   'case',
#   'use',
#   'textile',
#   'standard',
#   'value',
#   'occurrence',
#   'hostile',
#   'humour',
#   'assistant'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'concept',
#   'cycle',
#   'expansion',
#   'rural',
#   'anti',
#   'dollars',
#   'situations',
#   'cf',
#   'film',
#   'promotion',
#   'age',
#   'formations',
#   'index',
#   'concepts',
#   'attitudes',
#   'message',
#   'education',
#   'test',
#   'ml',
#   'london',
#   'contacts',
#   'editions',
#   'phrases',
#   'identification',
#   'accumulation',
#   'version',
#   'post',
#   'estimation',
#   'university',
#   'site',
#   'limitation',
#   'evolution',
#   'stable',
#   'offensive',
#   'patient',
#   'effective',
#   'initial',
#   'support',
#   'impact',
#   'time',
#   'colonial',
#   'sites',
#   'tests',
#   'circuits',
#   'daniel',
#   'justification',
#   'immigration',
#   'gain',
#   'stage',
#   'dominant',
#   'migration',
#   'fiction',
#   'club',
#   'oppose',
#   'reconstruction',
#   'interaction',
#   'plantations',
#   'stocks',
#   'nice',
#   'extra',
#   'illustration',
#   'anglo',
#   'case',
#   'christian',
#   'report',
#   'stock',
#   'formulation',
#   'james',
#   'restrictions',
#   'value',
#   'fluctuations',
#   'cycles',
#   'discrimination',
#   'textile',
#   'dense',
#   'william',
#   'changes',
#   'assistant',
#   'dollar',
#   'palestine',
#   'occurrence',
#   'plate',
#   'hostile'],
#  ['information',
#   'structures',
#   'aspects',
#   'op',
#   'concept',
#   'film',
#   'cycle',
#   'dollars',
#   'expansion',
#   'anti',
#   'situations',
#   'cf',
#   'rural',
#   'index',
#   'promotion',
#   'age',
#   'concepts',
#   'editions',
#   'message',
#   'london',
#   'identification',
#   'version',
#   'accumulation',
#   'attitudes',
#   'phrases',
#   'education',
#   'formations',
#   'contacts',
#   'test',
#   'evolution',
#   'effective',
#   'support',
#   'post',
#   'ml',
#   'site',
#   'estimation',
#   'university',
#   'initial',
#   'time',
#   'impact',
#   'daniel',
#   'colonial',
#   'stable',
#   'limitation',
#   'immigration',
#   'circuits',
#   'patient',
#   'sites',
#   'justification',
#   'club',
#   'offensive',
#   'fiction',
#   'value',
#   'plantations',
#   'christian',
#   'stocks',
#   'gain',
#   'stock',
#   'migration',
#   'interaction',
#   'oppose',
#   'stage',
#   'formulation',
#   'tests',
#   'dominant',
#   'case',
#   'illustration',
#   'dollar',
#   'textile',
#   'extra',
#   'fluctuations',
#   'changes',
#   'discrimination',
#   'cycles',
#   'report',
#   'anglo',
#   'james',
#   'system',
#   'rites',
#   'nice',
#   'reconstruction',
#   'use',
#   'law',
#   'william',
#   'aluminium',
#   'stages',
#   'occurrence',
#   'development',
#   'studies',
#   'research',
#   'sport',
#   'restrictions',
#   'palestine',
#   'alternative',
#   'irrigation',
#   'massive',
#   'incidents'],
#  ['information',
#   'structures',
#   'op',
#   'aspects',
#   'concept',
#   'film',
#   'cycle',
#   'cf',
#   'expansion',
#   'rural',
#   'situations',
#   'dollars',
#   'anti',
#   'promotion',
#   'age',
#   'index',
#   'message',
#   'phrases',
#   'concepts',
#   'accumulation',
#   'editions',
#   'attitudes',
#   'version',
#   'education',
# ...
#   'lectures',
#   'evolution',
#   'configuration',
#   'stock',
#   'law',
#   'gains',
#   'motivation',
#   'jacob',
#   'limitation',
#   'report',
#   'case',
#   'stage',
#   'standard',
#   'benjamin',
#   'humour',
#   'migration',
#   'messages',
#   'implications',
#   'stocks',
#   'offensive',
#   'development',
#   'tests',
#   'studies',
#   'prose',
#   'clan',
#   'world',
#   'history',
#   'chicago',
#   'massive',
#   'mental',
#   'eds',
#   'leaders',
#   'strict',
#   'sports',
#   'european',
#   'codes'],
#  ['information',
#   'op',
#   'structures',
#   'concept',
#   'aspects',
#   'film',
#   'situations',
#   'dollars',
#   'site',
#   'version',
#   'impact',
#   'promotion',
#   'message',
#   'cf',
#   'cycle',
#   'concepts',
#   'identification',
#   'sites',
#   'rural',
#   'anti',
#   'expansion',
#   'fiction',
#   'immigration',
#   'age',
#   'university',
#   'daniel',
#   'editions',
#   'sport',
#   'internet',
#   'post',
#   'club',
#   'patient',
#   'christian',
#   'formations',
#   'support',
#   'patients',
#   'attitudes',
#   'interaction',
#   'education',
#   'ere',
#   'contacts',
#   'london',
#   'corpus',
#   'management',
#   'cambridge',
#   'occurrence',
#   'phrases',
#   'reconstruction',
#   'index',
#   'effective',
#   'stable',
#   'illustration',
#   'performance',
#   'james',
#   'initial',
#   'colonial',
#   'alternative',
#   'discrimination',
#   'time',
#   'issues',
#   'justification',
#   'estimation',
#   'peter',
#   'accumulation',
#   'football',
#   'formulation',
#   'test',
#   'oppose',
#   'interactions',
#   'rites',
#   'oxford',
#   'evolution',
#   'william',
#   'anglo',
#   'configuration',
#   'patrick',
#   'leader',
#   'francis',
#   'case',
#   'motivation',
#   'dominant',
#   'gains',
#   'lectures',
#   'stock',
#   'nigeria',
#   'appropriation',
#   'messages',
#   'standard',
#   'prose',
#   'musical',
#   'migration',
#   'codes',
#   'sports',
#   'offensive',
#   'tests',
#   'jacob',
#   'implications',
#   'report',
#   'humour',
#   'limitation',
#   'stage',
#   'stocks',
#   'mental',
#   'world',
#   'law',
#   'restrictions',
#   'benjamin',
#   'dollar',
#   'development',
#   'studies',
#   'gain',
#   'mail',
#   'massive',
#   'strict'],
#  ['information',
#   'op',
#   'structures',
#   'concept',
#   'aspects',
#   'situations',
#   'site',
#   'film',
#   'dollars',
#   'impact',
#   'cycle',
#   'version',
#   'promotion',
#   'cf',
#   'message',
#   'sites',
#   'internet',
#   'identification',
#   'concepts',
#   'rural',
#   'expansion',
#   'fiction',
#   'anti',
#   'daniel',
#   'university',
#   'immigration',
#   'patient',
#   'age',
#   'post',
#   'christian',
#   'editions',
#   'formations',
#   'support',
#   'contacts',
#   'interaction',
#   'reconstruction',
#   'sport',
#   'club',
#   'london',
#   'patients',
#   'attitudes',
#   'cambridge',
#   'occurrence',
#   'colonial',
#   'corpus',
#   'effective',
#   'phrases',
#   'illustration',
#   'index',
#   'performance',
#   'stable',
#   'education',
#   'discrimination',
#   'initial',
#   'time',
#   'issues',
#   'management',
#   'james',
#   'alternative',
#   'oxford',
#   'case',
#   'justification',
#   'interactions',
#   'accumulation',
#   'estimation',
#   'peter',
#   'formulation',
#   'oppose',
#   'test',
#   'anglo',
#   'william',
#   'leader',
#   'patrick',
#   'configuration',
#   'migration',
#   'dominant',
#   'lectures',
#   'appropriation',
#   'rites',
#   'report',
#   'jacob',
#   'stock',
#   'gains',
#   'francis',
#   'standard',
#   'law',
#   'restrictions',
#   'messages',
#   'motivation',
#   'limitation',
#   'mail',
#   'humour',
#   'world',
#   'development',
#   'codes',
#   'implications',
#   'prose',
#   'evolution',
#   'mental',
#   'history',
#   'offensive'],
#  ['information',
#   'op',
#   'structures',
#   'concept',
#   'aspects',
#   'situations',
#   'site',
#   'film',
#   'internet',
#   'impact',
#   'dollars',
#   'version',
#   'cycle',
#   'promotion',
#   'cf',
#   'rural',
#   'message',
#   'sites',
#   'concepts',
#   'identification',
#   'anti',
#   'daniel',
#   'expansion',
#   'fiction',
#   'editions',
#   'university',
#   'immigration',
#   'post',
#   'corpus',
#   'christian',
#   'patient',
#   'age',
#   'support',
#   'cambridge',
#   'attitudes',
#   'interaction',
#   'formations',
#   'london',
#   'contacts',
#   'sport',
#   'patients',
#   'occurrence',
#   'phrases',
#   'reconstruction',
#   'effective',
#   'colonial',
#   'initial',
#   'illustration',
#   'management',
#   'discrimination',
#   'club',
#   'stable',
#   'performance',
#   'alternative',
#   'education',
#   'oxford',
#   'rites',
#   'issues',
#   'james',
#   'justification',
#   'index',
#   'william',
#   'peter',
#   'formulation',
#   'oppose',
#   'interactions',
#   'patrick',
#   'configuration',
#   'estimation',
#   'test',
#   'accumulation',
#   'appropriation',
#   'anglo',
#   'time',
#   'humour',
#   'dominant',
#   'motivation',
#   'lectures',
#   'benjamin',
#   'stock',
#   'leader',
#   'mail',
#   'francis',
#   'gains',
#   'migration',
#   'case',
#   'musical',
#   'messages',
#   'world',
#   'jacob',
#   'codes',
#   'standard',
#   'tests',
#   'nice',
#   'limitation',
#   'report',
#   'prose',
#   'restrictions',
#   'law',
#   'implications',
#   'history',
#   'studies',
#   'adolescents',
#   'web',
#   'development',
#   'strict',
#   'massive',
#   'leaders',
#   'sports',
#   'eds'],
#  ['op',
#   'information',
#   'structures',
#   'concept',
#   'aspects',
#   'film',
#   'situations',
#   'site',
#   'internet',
#   'impact',
#   'version',
#   'dollars',
#   'cycle',
#   'sites',
#   'promotion',
#   'message',
#   'cf',
#   'rural',
#   'anti',
#   'identification',
#   'concepts',
#   'immigration',
#   'fiction',
#   'university',
#   'post',
#   'daniel',
#   'expansion',
#   'patient',
#   'editions',
#   'club',
#   'support',
#   'patients',
#   'christian',
#   'sport',
#   'interaction',
#   'corpus',
#   'occurrence',
#   'cambridge',
#   'formations',
#   'age',
#   'contacts',
#   'colonial',
#   'attitudes',
#   'london',
#   'performance',
#   'reconstruction',
#   'illustration',
#   'index',
#   'effective',
#   'phrases',
#   'discrimination',
#   'issues',
#   'stable',
#   'alternative',
#   'initial',
#   'management',
#   'oxford',
#   'test',
#   'james',
#   'justification',
#   'configuration',
#   'nice',
#   'interactions',
#   'rites',
#   'formulation',
#   'education',
#   'peter',
#   'estimation',
#   'accumulation',
#   'appropriation',
#   'oppose',
#   'william',
#   'time',
#   'stock',
#   'web',
#   'leader',
#   'anglo',
#   'francis',
#   'patrick',
#   'mail',
#   'dominant',
#   'lectures',
#   'motivation',
#   'case',
#   'migration',
#   'codes',
#   'jacob',
#   'standard',
#   'report',
#   'messages',
#   'limitation',
#   'benjamin',
#   'tests',
#   'chicago',
#   'implications',
#   'humour',
#   'world',
#   'musical',
#   'gains',
#   'law',
#   'prose',
#   'format',
#   'adolescents',
#   'restrictions',
#   'leaders',
#   'mental',
#   'gain',
#   'strict',
#   'studies',
#   'festival',
#   'massive',
#   'stocks'],
#  ['information',
#   'op',
#   'concept',
#   'structures',
#   'site',
#   'aspects',
#   'situations',
#   'film',
#   'impact',
#   'internet',
#   'version',
#   'cycle',
#   'sites',
#   'message',
#   'dollars',
#   'promotion',
#   'anti',
#   'rural',
#   'concepts',
#   'identification',
#   'patient',
#   'patients',
#   'fiction',
#   'cf',
#   'immigration',
#   'daniel',
#   'post',
#   'expansion',
#   'university',
#   'sport',
#   'support',
#   'editions',
#   'management',
#   'performance',
#   'age',
#   'club',
#   'christian',
#   'formations',
#   'interaction',
#   'corpus',
#   'attitudes',
#   'occurrence',
#   'contacts',
#   'cambridge',
#   'london',
#   'reconstruction',
#   'discrimination',
#   'illustration',
#   'index',
#   'effective',
#   'phrases',
#   'colonial',
#   'initial',
#   'alternative',
#   'issues',
#   'web',
#   'oxford',
#   'interactions',
#   'test',
#   'configuration',
#   'stable',
#   'justification',
#   'education',
#   'rites',
#   'time',
#   'formulation',
#   'estimation',
#   'appropriation',
#   'accumulation',
#   'messages',
#   'peter',
#   'mail',
#   'patrick',
#   'oppose',
#   'migration',
#   'james',
#   'standard',
#   'dominant',
#   'lectures',
#   'motivation',
#   'leader',
#   'nice',
#   'case',
#   'anglo',
#   'william',
#   'francis',
#   'jacob',
#   'limitation',
#   'world',
#   'football',
#   'stock',
#   'report',
#   'marketing',
#   'massive',
#   'codes',
#   'sports',
#   'bush',
#   'humour',
#   'format',
#   'tests',
#   'musical',
#   'implications',
#   'benjamin',
#   'gains',
#   'supports',
#   'adolescents',
#   'restrictions',
#   'prose',
#   'strict',
#   'mental',
#   'gain',
#   'law'],
#  ['information',
#   'op',
#   'concept',
#   'structures',
#   'site',
#   'aspects',
#   'situations',
#   'film',
#   'impact',
#   'version',
#   'internet',
#   'sites',
#   'cycle',
#   'promotion',
#   'message',
#   'dollars',
#   'patient',
#   'anti',
#   'rural',
#   'identification',
#   'concepts',
#   'cf',
#   'patients',
#   'immigration',
#   'post',
#   'fiction',
#   'university',
#   'daniel',
#   'expansion',
#   'editions',
#   'performance',
#   'christian',
#   'support',
#   'formations',
#   'corpus',
#   'interaction',
#   'management',
#   'sport',
#   'occurrence',
#   'age',
#   'attitudes',
#   'contacts',
#   'test',
#   'reconstruction',
#   'cambridge',
#   'london',
#   'configuration',
#   'illustration',
#   'discrimination',
#   'interactions',
#   'phrases',
#   'club',
#   'alternative',
#   'colonial',
#   'oxford',
#   'issues',
#   'effective',
#   'stable',
#   'education',
#   'initial',
#   'index',
#   'peter',
#   'web',
#   'james',
#   'motivation',
#   'standard',
#   'patrick',
#   'bush',
#   'formulation',
#   'justification',
#   'lectures',
#   'time',
#   'stock',
#   'tests',
#   'rites',
#   'oppose',
#   'case',
#   'anglo',
#   'william',
#   'francis',
#   'migration',
#   'estimation',
#   'accumulation',
#   'appropriation',
#   'jacob',
#   'dominant',
#   'leader',
#   'nice',
#   'messages',
#   'massive',
#   'mail',
#   'musical',
#   'prose',
#   'codes',
#   'palestine',
#   'report',
#   'format',
#   'world',
#   'limitation',
#   'humour',
#   'football',
#   'implications',
#   'adolescents',
#   'stocks',
#   'benjamin',
#   'studies',
#   'stage',
#   'sports',
#   'michael',
#   'leaders',
#   'restrictions',
#   'supports',
#   'participant',
#   'nigeria'],
#  ['information',
#   'op',
#   'concept',
#   'structures',
#   'site',
#   'aspects',
#   'situations',
#   'film',
#   'impact',
#   'patient',
#   'version',
#   'cycle',
#   'internet',
#   'message',
#   'dollars',
#   'patients',
#   'promotion',
#   'anti',
#   'sites',
#   'concepts',
#   'immigration',
#   'identification',
#   'cf',
#   'fiction',
#   'university',
#   'daniel',
#   'rural',
#   'post',
#   'expansion',
#   'management',
#   'performance',
#   'corpus',
#   'christian',
#   'editions',
#   'discrimination',
#   'support',
#   'sport',
#   'occurrence',
#   'formations',
#   'interaction',
#   'test',
#   'cambridge',
#   'colonial',
#   'attitudes',
#   'configuration',
#   'contacts',
#   'reconstruction',
#   'age',
#   'bush',
#   'index',
#   'illustration',
#   'interactions',
#   'london',
#   'effective',
#   'issues',
#   'club',
#   'phrases',
#   'oxford',
#   'alternative',
#   'initial',
#   'stable',
#   'peter',
#   'web',
#   'james',
#   'patrick',
#   'standard',
#   'justification',
#   'william',
#   'tests',
#   'formulation',
#   'format',
#   'case',
#   'anglo',
#   'time',
#   'estimation',
#   'motivation',
#   'messages',
#   'lectures',
#   'oppose',
#   'leader',
#   'education',
#   'francis',
#   'appropriation',
#   'migration',
#   'dominant',
#   'mail',
#   'accumulation',
#   'codes',
#   'massive',
#   'jacob',
#   'rites',
#   'report',
#   'mental',
#   'adolescents',
#   'benjamin',
#   'michael',
#   'world',
#   'humour',
#   'stock',
#   'prose',
#   'restrictions',
#   'offensive',
#   'arthur',
#   'palestine',
#   'gains',
#   'stage',
#   'versions',
#   'implications',
#   'stress',
#   'leaders',
#   'magazine',
#   'studies',
#   'limitation',
#   'gain',
#   'development',
#   'connexion',
#   'sand',
#   'nice'],
#  ['op',
#   'information',
#   'concept',
#   'structures',
#   'site',
#   'aspects',
#   'situations',
#   'patient',
#   'impact',
#   'film',
#   'version',
#   'internet',
#   'message',
#   'patients',
#   'cycle',
#   'promotion',
#   'anti',
#   'sites',
#   'concepts',
#   'identification',
#   'immigration',
#   'cf',
#   'daniel',
#   'post',
#   'university',
#   'dollars',
#   'fiction',
#   'performance',
#   'rural',
#   'editions',
#   'test',
#   'expansion',
#   'support',
#   'sport',
#   'christian',
#   'corpus',
#   'management',
#   'formations',
#   'colonial',
#   'interaction',
#   'contacts',
#   'configuration',
#   'cambridge',
#   'occurrence',
#   'discrimination',
#   'attitudes',
#   'age',
#   'reconstruction',
#   'illustration',
#   'london',
#   'interactions',
#   'web',
#   'issues',
#   'index',
#   'alternative',
#   'stable',
#   'peter',
#   'oxford',
#   'phrases',
#   'club',
#   'standard',
#   'initial',
#   'effective',
#   'tests',
#   'patrick',
#   'migration',
#   'james',
#   'time',
#   'motivation',
#   'formulation',
#   'education',
#   'justification',
#   'messages',
#   'estimation',
#   'case',
#   'format',
#   'william',
#   'lectures',
#   'jacob',
#   'adolescents',
#   'rites',
#   'oppose',
#   'leader',
#   'appropriation',
#   'marketing',
#   'francis',
#   'dominant',
#   'windows',
#   'world',
#   'anglo',
#   'accumulation',
#   'report',
#   'mail',
#   'stress',
#   'codes',
#   'menu',
#   'gains',
#   'bush',
#   'massive',
#   'gain',
#   'leaders',
#   'michael',
#   'benjamin',
#   'prose',
#   'versions',
#   'palestine',
#   'implications',
#   'mental',
#   'humour',
#   'musical',
#   'participant',
#   'studies',
#   'sports',
#   'stock',
#   'limitation',
#   'restrictions',
#   'development',
#   'history',
#   'cognitive',
#   'american',
#   'questionnaire',
#   'research',
#   'connexion'],
#  ['op',
#   'information',
#   'concept',
#   'structures',
#   'site',
#   'aspects',
#   'film',
#   'situations',
#   'impact',
#   'version',
#   'internet',
#   'patient',
#   'message',
#   'cycle',
#   'promotion',
#   'anti',
#   'identification',
#   'concepts',
#   'patients',
#   'sites',
#   'immigration',
#   'dollars',
#   'fiction',
#   'performance',
#   'post',
#   'university',
#   'management',
#   'rural',
#   'daniel',
#   'test',
#   'cf',
#   'corpus',
#   'interaction',
#   'support',
#   'editions',
#   'colonial',
#   'discrimination',
#   'expansion',
#   'christian',
#   'attitudes',
#   'formations',
#   'phrases',
#   'occurrence',
#   'sport',
#   'cambridge',
#   'interactions',
#   'reconstruction',
#   'illustration',
#   'contacts',
#   'motivation',
#   'configuration',
#   'issues',
#   'london',
#   'age',
#   'club',
#   'james',
#   'index',
#   'initial',
#   'effective',
#   'stable',
#   'patrick',
#   'tests',
#   'oxford',
#   'web',
#   'alternative',
#   'time',
#   'estimation',
#   'peter',
#   'justification',
#   'william',
#   'formulation',
#   'messages',
#   'case',
#   'musical',
#   'migration',
#   'lectures',
#   'appropriation',
#   'education',
#   'jacob',
#   'standard',
#   'marketing',
#   'leader',
#   'anglo',
#   'rites',
#   'oppose',
#   'dominant',
#   'codes',
#   'format',
#   'humour',
#   'accumulation',
#   'adolescents',
#   'mental',
#   'francis',
#   'gain',
#   'questionnaire',
#   'prose',
#   'report',
#   'world',
#   'stock',
#   'stress',
#   'benjamin',
#   'nice',
#   'michael',
#   'studies',
#   'development',
#   'leaders',
#   'stage',
#   'gains',
#   'participant',
#   'nigeria',
#   'research',
#   'cognitive',
#   'massive',
#   'implications',
#   'mail',
#   'ratio',
#   'restaurant',
#   'finance',
#   'menu',
#   'narrative',
#   'limitation',
#   'history',
#   'immigrants',
#   'palestine'],
#  ['op',
#   'information',
#   'concept',
#   'film',
#   'site',
#   'structures',
#   'aspects',
#   'situations',
#   'impact',
#   'version',
#   'internet',
#   'patient',
#   'message',
#   'patients',
#   'promotion',
#   'cycle',
#   'anti',
#   'immigration',
#   'fiction',
#   'sites',
#   'identification',
#   'concepts',
#   'dollars',
#   'daniel',
#   'performance',
#   'post',
#   'university',
#   'management',
#   'corpus',
#   'cf',
#   'support',
#   'rural',
#   'sport',
#   'test',
#   'interaction',
#   'christian',
#   'colonial',
#   'expansion',
#   'editions',
#   'occurrence',
#   'attitudes',
#   'formations',
#   'configuration',
#   'contacts',
#   'club',
#   'interactions',
#   'phrases',
#   'discrimination',
#   'cambridge',
#   'web',
#   'illustration',
#   'peter',
#   'issues',
#   'age',
#   'motivation',
#   'patrick',
#   'london',
#   'reconstruction',
#   'james',
#   'initial',
#   'oxford',
#   'alternative',
#   'index',
#   'format',
#   'effective',
#   'stable',
#   'standard',
#   'tests',
#   'william',
#   'leader',
#   'migration',
#   'jacob',
#   'messages',
#   'case',
#   'adolescents',
#   'justification',
#   'lectures',
#   'codes',
#   'formulation',
#   'estimation',
#   'education',
#   'time',
#   'humour',
#   'appropriation',
#   'oppose',
#   'rites',
#   'francis',
#   'festival',
#   'dominant',
#   'prose',
#   'accumulation',
#   'anglo',
#   'mental',
#   'benjamin',
#   'arthur',
#   'marketing',
#   'musical',
#   'michael',
#   'menu',
#   'questionnaire',
#   'report',
#   'adolescent',
#   'stock',
#   'gain',
#   'studies',
#   'stress',
#   'stage',
#   'leaders',
#   'narrative',
#   'world',
#   'cognitive',
#   'restaurant',
#   'mail',
#   'gains',
#   'finance',
#   'versions',
#   'participant',
#   'history',
#   'invitation',
#   'champion',
#   'supports',
#   'nice',
#   'massive']]

# %%
migrant[migrant["word"]=="adorno"]
# Out:
#        word  year  count language    Rank
# 177  adorno  1800    904  spanish  3751.0
# 178  adorno  1812    234  italian  4725.0
# 179  adorno  1971  17249   german  4639.0

# %% [markdown]
# ### Calculate uses of all pairs of langauges

# %%
languages = ["english","french","german","italian","spanish"]
exclude = "_exc_all"

for language_out in languages:
    for language_in in languages:
        if language_out == language_in:
            continue
        words, uses = use(language_out,language_in,range(1850,2009),exclude)
        
        with open("Fig3_data/" + language_out + "_" + language_in + "_exc_all_new_1800" + '.txt', 'w') as f:
            for year_words in words:
                for j,word in enumerate(year_words):
                    if j == len(year_words)-1:
                        f.write(word)
                    else:
                        f.write(word+",")
        
                f.write("\n")
            
            for i,value in enumerate(uses):
                if i == len(uses)-1:
                    f.write(str(value))
                else:
                    f.write(str(value)+",")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [03:13<00:00,  1.21s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:29<00:00,  1.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:39<00:00,  1.00s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:58<00:00,  1.12s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:49<00:00,  1.06s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:44<00:00,  1.04s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:41<00:00,  1.01s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:38<00:00,  1.01it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:35<00:00,  1.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:43<00:00,  1.03s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:42<00:00,  1.02s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:47<00:00,  1.05s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:27<00:00,  1.08it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:46<00:00,  1.05s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:47<00:00,  1.06s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:28<00:00,  1.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:22<00:00,  1.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:51<00:00,  1.08s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:55<00:00,  1.11s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [02:43<00:00,  1.03s/it]

# %% [markdown]
# ## See the results

# %%
def read_words(language_out,language_in,exclude="_exc_all"):

    with open("Fig3_data/" + language_out + "_" + language_in + exclude + '_new_1800.txt', 'r') as f:
        lines = f.readlines()
    
        complete_list = [line.strip() for line in lines[:-1]]
    
        list_of_words = []
        for i in range(len(complete_list)):
            year_words = []
            
            for word in complete_list[i].split(","):
                year_words.append(word)
            
                list_of_words.append(year_words)
                
    return(list_of_words)

def read_uses(language_out,language_in,exclude="_exc_all"):
    with open("Fig3_data/" + language_out + "_" + language_in + exclude + '_new_1800.txt', 'r') as f:
        lines = f.readlines()
        
#         complete_list = [line.strip() for line in lines[-1]]
#         print(complete_list)
        lista = lines[-1].split(',')
        use = [float(a) for a in lista]
        
    return(use)

def use_of_word(word,year,language,exclude="_exc_all"):
    lan_in_df = pd.read_csv("Top5000/"+"top_"+language + exclude+ "_new_1800.csv",
                dtype={"0":str, "1":np.int32, "2":np.int32},
                names = ["word","year","count"],
                header=None,index_col=False)
    
    lan_in_year = lan_in_df[lan_in_df["year"]==year].copy()
    lan_in_year["Rank"]= lan_in_year["count"].rank(ascending=False, method='first')
    lan_in_year = lan_in_year.sort_values(by="Rank")
    
    normalization = np.sum(lan_in_year["count"])

    w = lan_in_year[lan_in_year["word"]==word]
    return(w)

english_spanish_w = read_words("english","spanish")
english_spanish_u = read_uses("english","spanish")

# %%
english_spanish_w = read_words("english","spanish","_exc_all")
english_spanish_w[-1]
# Out:
# ['control',
#  'sector',
#  'university',
#  'similar',
#  'op',
#  'internet',
#  'miles',
#  'john',
#  'define',
#  'web',
#  'american',
#  'hotel',
#  'international',
#  'paul',
#  'cambridge',
#  'musical',
#  'world',
#  'agenda',
#  'marketing',
#  'robert',
#  'visual',
#  'oxford',
#  'ritual',
#  'digital',
#  'conceptual',
#  'laura',
#  'william',
#  'george',
#  'history',
#  'james',
#  'research',
#  'richard',
#  'medieval',
#  'charles',
#  'review',
#  'development',
#  'bar',
#  'studies',
#  'chicago',
#  'peter',
#  'nuclear',
#  'national',
#  'economic',
#  'michael',
#  'study',
#  'society',
#  'software',
#  'informal',
#  'human',
#  'london',
#  'genes',
#  'management',
#  'bush',
#  'political',
#  'roles',
#  'law']

# %% [markdown]
# ### Small test to see that the uses calculated are correct

# %% [markdown]
# Function to run queries of Google Ngram Viewer

# %%
import requests 
import urllib 
  
def runQuery(query, start_year,  
             end_year, corpus="es-2012", 
             smoothing=0,case_insensitive=True): 
  
    # converting a regular string to  
    # the standard URL format 
    # eg: "geeks for,geeks" will 
    # convert to "geeks%20for%2Cgeeks" 
    query = urllib.parse.quote(query) 
  

    # creating the URL 
    if case_insensitive == True:
        url = ('https://books.google.com/ngrams/json?content=' + query +
    '&year_start=' + str(start_year) + '&year_end=' +
    str(end_year) + '&corpus=' + str(corpus) + '&smoothing=' +
    str(smoothing) + "&case_insensitive=" + str(case_insensitive)+ '' )
  
    else:
        url = ('https://books.google.com/ngrams/json?content=' + query +
    '&year_start=' + str(start_year) + '&year_end=' +
    str(end_year) + '&corpus=' + str(corpus) + '&smoothing=' +
    str(smoothing) + '' )
        
    # requesting data from the above url 
    response = requests.get(url) 
  
    # extracting the json data from the response we got 
    output = response.json() 
  
    # creating a list to store the ngram data 
    return_data = [] 
  
    if len(output) == 0: 
        # if no data returned from site, 
        # print the following statement 
        return "No data available for this Ngram."
    else: 
        # if data returned from site, 
        # store the data in return_data list 
        for num in range(len(output)): 
            
              # getting the name 
            return_data.append((output[num]['ngram'],  
                                  
                                # getting ngram data 
                                output[num]['timeseries'])  
                               ) 
  
    return return_data 

runQuery("the",2000,2001,"es-2012",0,True)
# Out:
# [('the (All)', [0.0007015032746329752, 0.0006878203437837849]),
#  ('the', [0.0005046764272265136, 0.00048433145275339484]),
#  ('The', [0.00019017051090486348, 0.00019652048649732023]),
#  ('THE', [6.64784965920262e-06, 6.957033292565029e-06]),
#  ('THe', [4.243421170002648e-09, 4.873388803616763e-09]),
#  ('tHe', [2.6521382867628063e-09, 2.7074382735747804e-09]),
#  ('ThE', [5.30427646250331e-10, 3.2489257950629735e-09]),
#  ('tHE', [1.060855292500662e-09, 5.414876325104956e-10])]

# %% [markdown]
# Get the counts of three words in 1999 with my results

# %%
high_m = use_of_word("high",1999,"english","")
seven_m = use_of_word("seven",1999,"english","")
operation_m = use_of_word("operation",1999,"english","")
operation_m
# Out:
#               word  year    count   Rank
# 1295784  operation  1999  1733122  785.0

# %% [markdown]
# And get them with the query

# %%
high = runQuery("high",1999,2000,"en-2012",0,True)[0][1][0]
seven = runQuery("seven",1999,2000,"en-2012",0,True)[0][1][0]
operation = runQuery("operation",1999,2000,"en-2012",0,True)[0][1][0]

# %%
print(high/seven, high_m["count"].values / seven_m["count"].values)
print(high/operation, high_m["count"].values / operation_m["count"].values)
print(seven/operation,seven_m["count"].values / operation_m["count"].values)
# Out:
# 5.111869548964236 [5.11312183]
# 4.897319317511588 [4.89965738]
# 0.9580290088787339 [0.95825164]

# %%
migrant[migrant["word"]=="anemia"]
# Out:
#         word  year  count    Rank language
# 1199  anemia  1745    364   215.0  spanish
# 1200  anemia  1929   3398  4923.0  italian

# %% [markdown]
# # Graphs

# %%
def graph(language_outs,language_ins,excludes,title,ylimit=None,legend=True,
         save = False):
    colors = {"english":"steelblue","french":"darkorange","german":"darkviolet",
         "italian":"green","spanish":"brown"}
    
    for i in range(len(language_outs)):
        language_out = language_outs[i]
        language_in = language_ins[i]
        exclude = excludes[i]
    

        uses = read_uses(language_out,language_in,exclude)
    
        plt.plot(range(1900,2008),uses,label = language_in,
                color = colors[language_in])

    if ylimit != None:
        plt.ylim([0,ylimit])
    else:
        plt.gca().set_ylim(bottom=0)

    
    if legend == True:
        plt.legend()
    plt.title(title,fontsize=16,y=1,pad=-20)
    plt.xlabel("Year",fontsize=14)    
    plt.ylabel("Use",fontsize=14)

   
    if save != False:
        plt.savefig('Fig3_data/'+ save +'.png',bbox_inches = "tight")

        
    plt.show()

# %%
read_uses("spanish","german","_exc_all")
# Out:
# [6.551672604717694e-05,
#  8.873609053223907e-05,
#  0.0,
#  0.0,
#  0.00014494537779634746,
#  8.393974046522163e-05,
#  0.0,
#  0.0,
#  0.00021917613999269023,
#  0.0002427299844213632,
#  0.00018887988080153604,
#  0.0006720558130112654,
#  0.0002383354554899071,
#  0.00019579453717451402,
#  0.00027681801222028323,
#  0.00028889983253297264,
#  0.00017512951993994895,
#  7.771281211178298e-05,
#  0.0001519209963157669,
#  0.00021033864856269082,
#  0.00011839981734089854,
#  0.0002885340433739592,
#  0.00013736322211549076,
#  0.00039226386223368116,
#  0.00024758299115574444,
#  0.00045129525077950924,
#  0.0002689605063729286,
#  0.00031805408554395193,
#  0.000554899170080808,
#  0.0003198779246186283,
#  0.0006085252996243922,
#  0.00023912688973936984,
#  0.00042418145918629005,
#  0.0004853668686112847,
#  0.00033531438791506565,
#  0.0003348283426655355,
#  0.00042213167596946786,
#  0.00042039672311463546,
#  0.00032195615651717073,
#  0.0002498838445188282,
#  0.00044392756569865035,
#  0.00037758284868710795,
#  0.00036986084419613684,
#  0.00045520637272504835,
#  0.0005419765182243544,
#  0.0004246760625196951,
#  0.0004938199132653031,
#  0.0004485786774531367,
#  0.0004325367704185691,
#  0.0005135466239495983,
#  0.0004827635849814765,
#  0.0007426416186034005,
#  0.0004989016983434453,
#  0.000581427163357437,
#  0.00048141923327663365,
#  0.000548234376503235,
#  0.0005022530037086947,
#  0.0004991842504961619,
#  0.0006228991827019435,
#  0.0005090260778187989,
#  0.0005135540400303462,
#  0.0004962943109886709,
#  0.0007070510380169649,
#  0.0005419107625168907,
#  0.0006233026366155976,
#  0.0004678326859096159,
#  0.00038946956627657254,
#  0.0004060461800472693,
#  0.0006173842578239423,
#  0.0003559332118576425,
#  0.00041766597319189134,
#  0.00030276957499497756,
#  0.00033442748413476585,
#  0.000236871284498677,
#  0.0005212064054509168,
#  0.0008021958801578581,
#  0.0005305676290985506,
#  0.0005270323165017384,
#  0.0005647336699189151,
#  0.0003896182965559254,
#  0.0003757786770653406,
#  0.0003826290130037112,
#  0.0005435819382751862,
#  0.00030339702649319225,
#  0.000473012157606126,
#  0.00045696093776331575,
#  0.0003829593744654509,
#  0.0004297504554725161,
#  0.0004756356095045509,
#  0.0003967091897012054,
#  0.0005123177446962328,
#  0.00046708420861824853,
#  0.0005605791513124473,
#  0.0006352109079437567,
#  0.000674784873043711,
#  0.0007245231127525632,
#  0.0005925475145680622,
#  0.0006655542140903832,
#  0.0005126821623546715,
#  0.00046509336879843333,
#  0.0004416059225566104,
#  0.0005173339361696856,
#  0.0005256743059216369,
#  0.0006241702920096308,
#  0.0004345748700869914,
#  0.0005090078579745491,
#  0.0004826914673959313,
#  0.0006939362781718831,
#  0.0006063729250016547,
#  0.0005549298857214659,
#  0.0006762906955124073,
#  0.0006353658484242652,
#  0.0005702053542526485,
#  0.0006728987484167835,
#  0.0005498495214204919,
#  0.0006152305819327015,
#  0.0006157935025793079,
#  0.0007150270938699506,
#  0.0005889070663462954,
#  0.0006856049160723434,
#  0.0006036407895185458,
#  0.0008409254241717211,
#  0.0007821856047642165,
#  0.0007672751120339359,
#  0.000918289461047017,
#  0.00092162330645217,
#  0.0010162993024646013,
#  0.0009470676209388698,
#  0.0009386155430002637,
#  0.0009565351047645138,
#  0.0009577471578598102,
#  0.0009978252561756143,
#  0.0010637729263584873,
#  0.0010018777269284692,
#  0.001260536518624667,
#  0.0012467786322135467,
#  0.001407921528913097,
#  0.001330975945862903,
#  0.0013331121156834418,
#  0.0012079190576517193,
#  0.0012071704674564835,
#  0.0011617573801413813,
#  0.0011912775582006067,
#  0.0013249751689863424,
#  0.0014947126284739587,
#  0.0011494578191898438,
#  0.001534257368654934,
#  0.0014178149559322718,
#  0.0015017480846849314,
#  0.0014485970366788562,
#  0.0015616942585202774,
#  0.0013845656149634943,
#  0.001647975911696023,
#  0.0016661851066154993,
#  0.0017006975336209616,
#  0.0018686406218834449,
#  0.0016901050699863467,
#  0.0015764751651825737,
#  0.0015978340236088245]

# %%
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

languages = ["english","french","german","italian","spanish"]
languagesM = ["English","French","German","Italian","Spanish"]
# exc = ["","_exc_all","_exc_none"]
colors = {"english":"steelblue","french":"darkorange","german":"darkviolet",
         "italian":"green","spanish":"brown"}
# exclude_title = ["Exclude each", "Exclude all", "Exclude none"]
ex = "_exc_all"

fig, axs = plt.subplots(2, 5, figsize=(14, 6), sharex=True)



for j,lan in enumerate(languages):
    
    for k,lan2 in enumerate(languages):
        if lan == lan2:
            continue
                
        lista0 = read_uses(lan,lan2,ex)
#         print(lan,lan2,lista0[-1])
    
        axs[0][j].plot(range(1900,2008),lista0[50:-1],
                        color= colors[lan2],linewidth=2)
        
#         lista1 = read_uses(lan2,lan,ex)
        axs[1][k].plot(range(1900,2008),lista0[50:-1],
                        color= colors[lan],linewidth=2)
    
        axs[0][k].ticklabel_format(axis="y",style="sci",scilimits = (0,0))  
        axs[1][k].ticklabel_format(axis="y",style="sci",scilimits= (0,0))  

#         if max(lista0)>max0j:
#             max0j = max(lista0)
            
#         if max(lista1)>max1j:
#             max1j = max(lista1)
            
         
    axs[0][0].set_ylabel(r"Use",fontsize=12)
    axs[1][0].set_ylabel(r"Use",fontsize=12)
    
#     max0j = max0j//0.005*0.005+0.005
#     max1j = max1j//0.005*0.005+0.005
    
#     ys0 = [0,np.around(max0j,3)]
#     axs[0][j].set_yticks(ys0)
#     axs[0][j].set_yticklabels(ys0, fontsize=8)
#     axs[0][j].yaxis.set_minor_locator(AutoMinorLocator())
    axs[0][j].tick_params(axis='y', labelrotation=90)

#     ys1 = [0,np.around(max1j,3)]
#     axs[1][j].set_yticks(ys1)
#     axs[1][j].set_yticklabels(ys1, fontsize=8)
#     axs[1][j].yaxis.set_minor_locator(AutoMinorLocator())
    axs[1][j].tick_params(axis='y', labelrotation=90)
    
    axs[0][j].set_title(languagesM[j],fontsize=15)
    axs[-1][j].set_xlabel(r"Year",fontsize=12)
        
axs[0][-1].yaxis.set_label_position("right")
axs[0][-1].set_ylabel("Influencing",fontsize=12)
axs[1][-1].yaxis.set_label_position("right")
axs[1][-1].set_ylabel("Influenced by",fontsize=12)

            
ys00 = [0,0.01,0.02]
axs[0][0].set_yticks(ys00)
axs[0][0].set_yticklabels(ys00, fontsize=10)
axs[0][0].yaxis.set_minor_locator(AutoMinorLocator()) 


ys01 = [0,0.005,0.01]
axs[0][1].set_yticks(ys01)
axs[0][1].set_yticklabels(ys01, fontsize=10)
axs[0][1].yaxis.set_minor_locator(AutoMinorLocator()) 


ys02 = [0,0.005,0.01]
axs[0][2].set_yticks(ys02)
axs[0][2].set_yticklabels(ys02, fontsize=10)
axs[0][2].yaxis.set_minor_locator(AutoMinorLocator()) 

ys03 = [0,0.005,0.01]
axs[0][3].set_yticks(ys03)
axs[0][3].set_yticklabels(ys03, fontsize=10)
axs[0][3].yaxis.set_minor_locator(AutoMinorLocator()) 

ys04 = [0,0.002,0.005]
axs[0][4].set_yticks(ys04)
axs[0][4].set_yticklabels(ys04, fontsize=10)
axs[0][4].yaxis.set_minor_locator(AutoMinorLocator()) 


ys10 = [0,0.005,0.01]
axs[1][0].set_yticks(ys10)
axs[1][0].set_yticklabels(ys10, fontsize=10)
axs[1][0].yaxis.set_minor_locator(AutoMinorLocator()) 

ys11 = [0,0.005,0.01]
axs[1][1].set_yticks(ys11)
axs[1][1].set_yticklabels(ys11, fontsize=10)
axs[1][1].yaxis.set_minor_locator(AutoMinorLocator()) 

ys12 = [0,0.01,0.02]
axs[1][2].set_yticks(ys12)
axs[1][2].set_yticklabels(ys12, fontsize=10)
axs[1][2].yaxis.set_minor_locator(AutoMinorLocator()) 

ys13 = [0,0.005,0.01]
axs[1][3].set_yticks(ys13)
axs[1][3].set_yticklabels(ys13, fontsize=10)
axs[1][3].yaxis.set_minor_locator(AutoMinorLocator()) 

ys14 = [0,0.005,0.01]
axs[1][4].set_yticks(ys14)
axs[1][4].set_yticklabels(ys14, fontsize=10)
axs[1][4].yaxis.set_minor_locator(AutoMinorLocator()) 
            
            
import matplotlib.patches as mpatches    
brown_patch = mpatches.Patch(color='brown', label='Spanish')
green_patch = mpatches.Patch(color='green', label='Italian')
darkviolet_patch = mpatches.Patch(color='darkviolet', label='German')
darkorange_patch = mpatches.Patch(color='darkorange', label='French')
steelblue_patch = mpatches.Patch(color='steelblue', label='English')


fig.subplots_adjust(bottom=0.25)
plt.legend(handles=[steelblue_patch,darkorange_patch,darkviolet_patch,green_patch,brown_patch],
    loc="upper center",
    ncol=5,
    bbox_to_anchor=(0.5, 0.16),
    bbox_transform=fig.transFigure )


# plt.savefig('Fig3_data/full15.png',bbox_inches = "tight")
plt.savefig('Fig3_data/final_image' + ex + '_new_1800.pdf',bbox_inches = "tight")

# %%
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

languages = ["english","french","german","italian","spanish"]
languagesM = ["English","French","German","Italian","Spanish"]
# exc = ["","_exc_all","_exc_none"]
colors = {"english":"steelblue","french":"darkorange","german":"darkviolet",
         "italian":"green","spanish":"brown"}
# exclude_title = ["Exclude each", "Exclude all", "Exclude none"]
ex = "_exc_all"

fig, axs = plt.subplots(2, 5, figsize=(14, 6), sharex=True,sharey=True)



for j,lan in enumerate(languages):
#         axs[i][j].
#     max0j = 0
#     max1j = 0
    for k,lan2 in enumerate(languages):
        if lan == lan2:
            continue
                
        lista0 = read_uses(lan,lan2,ex)
    
        axs[0][j].plot(range(1900,2008),lista0[50:-1],
                        color= colors[lan2],linewidth=2)
        
#         lista1 = read_uses(lan2,lan,ex)
        axs[1][k].plot(range(1900,2008),lista0[50:-1],
                        color= colors[lan],linewidth=2)
    
#         axs[0][k].ticklabel_format(axis="y",style="sci",scilimits = (0,0))  
#         axs[1][k].ticklabel_format(axis="y",style="sci",scilimits= (0,0))  

#         if max(lista0)>max0j:
#             max0j = max(lista0)
            
#         if max(lista1)>max1j:
#             max1j = max(lista1)
            
         
    axs[0][0].set_ylabel(r"Use",fontsize=12)
    axs[1][0].set_ylabel(r"Use",fontsize=12)
    
#     max0j = max0j//0.005*0.005+0.005
#     max1j = max1j//0.005*0.005+0.005
    
#     ys0 = [0,np.around(max0j,3)]
#     axs[0][j].set_yticks(ys0)
#     axs[0][j].set_yticklabels(ys0, fontsize=8)
#     axs[0][j].yaxis.set_minor_locator(AutoMinorLocator())
    axs[0][j].tick_params(axis='y', labelrotation=90)

#     ys1 = [0,np.around(max1j,3)]
#     axs[1][j].set_yticks(ys1)
#     axs[1][j].set_yticklabels(ys1, fontsize=8)
#     axs[1][j].yaxis.set_minor_locator(AutoMinorLocator())
    axs[1][j].tick_params(axis='y', labelrotation=90)
    
    axs[0][j].set_title(languagesM[j],fontsize=15)
    axs[-1][j].set_xlabel(r"Year",fontsize=12)
        
axs[0][-1].yaxis.set_label_position("right")
axs[0][-1].set_ylabel("Influencing",fontsize=12)
axs[1][-1].yaxis.set_label_position("right")
axs[1][-1].set_ylabel("Influenced by",fontsize=12)

            
import matplotlib.patches as mpatches    
brown_patch = mpatches.Patch(color='brown', label='Spanish')
green_patch = mpatches.Patch(color='green', label='Italian')
darkviolet_patch = mpatches.Patch(color='darkviolet', label='German')
darkorange_patch = mpatches.Patch(color='darkorange', label='French')
steelblue_patch = mpatches.Patch(color='steelblue', label='English')


ys00 = [0,0.01,0.02]
axs[0][0].set_yticks(ys00)
axs[0][0].set_yticklabels(ys00, fontsize=10)
axs[0][0].yaxis.set_minor_locator(AutoMinorLocator()) 


fig.subplots_adjust(bottom=0.25)
plt.legend(handles=[steelblue_patch,darkorange_patch,darkviolet_patch,green_patch,brown_patch],
    loc="upper center",
    ncol=5,
    bbox_to_anchor=(0.5, 0.16),
    bbox_transform=fig.transFigure )


# plt.savefig('Fig3_data/full15.png',bbox_inches = "tight")
plt.savefig('Fig3_data/final_image' + ex + "_same_scale_new_1800.pdf",bbox_inches = "tight")
